# %% [markdown]
# This code is to classify the selected examples automatically for those criteria that allow automatic classification.

# %%
import pandas as pd
import xlrd
import re
from re import search

# %%
# opens the excel sheet and reads it
# excel sheet needs to be in the same working directory as this file

file = 'qui_selected_rows_sorted.xls'
data = pd.ExcelFile(file)

 # returns the all the sheet names within the excel file
print(data.sheet_names)
# Out:
# ['Sheet1']

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame = data.parse('Sheet1')
data_frame.info

# only shows the first 10 rows
data_frame.head(10)
# Out:
#    recherche occurrence  wh  int  other  \
# 0  Mot exact        qui NaN  NaN    NaN
# 1  Mot exact        qui NaN  NaN    NaN
# 2  Mot exact        qui NaN  NaN    NaN
# 3  Mot exact        qui NaN  NaN    NaN
# 4  Mot exact        qui NaN  NaN    NaN
# 5  Mot exact        qui NaN  NaN    NaN
# 6  Mot exact        qui NaN  NaN    NaN
# 7  Mot exact        qui NaN  NaN    NaN
# 8  Mot exact        qui NaN  NaN    NaN
# 9  Mot exact        qui NaN  NaN    NaN
#
#                                              segment enregistrement  \
# 0               trés bien qui habitent la rue hein ?  ESLO1_ENT_017
# 1                           qui habitent le ah bon ?  ESLO1_ENT_017
# 2  qu'est-ce qui vous plaît et qu'est-ce qui vous...  ESLO1_ENT_017
# 3  quelles sont les choses qui vous plaisent le p...  ESLO1_ENT_017
# 4  qu'est-ce que vous pensez des des femmes marié...  ESLO1_ENT_017
# 5      qu'est-ce qui leur plaît dans leurs loisirs ?  ESLO1_ENT_017
# 6  alors à Orléans qui est-ce qui va à la maison ...  ESLO1_ENT_017
# 7  à votre avis qu'est-ce qui fait que les enfant...  ESLO1_ENT_017
# 8  quelles sont les p- les personnes qui comptent...  ESLO1_ENT_017
# 9  vous pouvez expliquer un peu ce qui s'est passé ?  ESLO1_ENT_017
#
#      transcription locuteur  debut (ms)   fin (ms)  debut (hh:mm:ss)  \
# 0  ESLO1_ENT_017_C    QB100     97160.0    98641.0          0.001123
# 1  ESLO1_ENT_017_C       CS    370289.0   371481.0          0.004282
# 2  ESLO1_ENT_017_C       CS    730114.0   738206.0          0.008449
# 3  ESLO1_ENT_017_C       CS    734543.0   738206.0          0.008495
# 4  ESLO1_ENT_017_C       CS    768372.0   772569.0          0.008889
# 5  ESLO1_ENT_017_C    QB100   1031781.0  1038519.0          0.011933
# 6  ESLO1_ENT_017_C       CS   1062853.0  1065278.0          0.012292
# 7  ESLO1_ENT_017_C       CS   1366299.0  1373565.0          0.015810
# 8  ESLO1_ENT_017_C       CS   1859247.0  1864205.0          0.021516
# 9  ESLO1_ENT_017_C       CS   2026649.0  2038217.0          0.023449
#
#    fin (hh:mm:ss)
# 0        0.001134
# 1        0.004294
# 2        0.008542
# 3        0.008542
# 4        0.008935
# 5        0.012014
# 6        0.012326
# 7        0.015891
# 8        0.021574
# 9        0.023588

# %%
# reads in the spreadsheet data

workbook = xlrd.open_workbook('qui_selected_rows_sorted.xls')
sheet = workbook.sheet_by_name('Sheet1')

row_count = sheet.nrows
col_count = sheet.ncols
print(f'Total rows: {row_count}\nTotal columns: {col_count}')
# Out:
# Total rows: 3162
# Total columns: 13

# %% [markdown]
# We're now going to create a new list of lists out of the file, and populate the empty columns with as much data as possible.
#
# The data that should be easy to classify automatically are: est-ce que / wh- at the beginning or end of sentence / presence of c'est.

# %%
# initialises list of lists
all_rows = []
unwanted_segment = 'qu\'est-ce\squi'

for rx in range(sheet.nrows): # rx is an int, row is a list 
    row = sheet.row(rx)
    
    # initialises list that will contain our data
    data_list = []

    # populates list that stores all rows
    data_list.append(row[0].value)
    data_list.append(row[1].value)
    data_list.append(row[2].value) # wh
    data_list.append(row[3].value) # int
    data_list.append(row[4].value) # other
    # excludes all utterances containing 'qu'est-ce qui'
    utterance = row[5].value
    if search(unwanted_segment, utterance):
        # excludes unwanted segments
        continue
    else:
        data_list.append(utterance) # segment
    data_list.append(row[6].value)
    data_list.append(row[7].value)
    data_list.append(row[8].value)
    data_list.append(row[9].value)
    data_list.append(row[10].value)
    data_list.append(row[11].value)
    data_list.append(row[12].value)

    all_rows.append(data_list)
        
# prints extracted rows metrics
print(f'We created a list that embeds {len(all_rows)} lists.')
# Out:
# ['recherche', 'occurrence', 'wh', 'int', 'other', 'segment', 'enregistrement', 'transcription', 'locuteur', 'debut (ms)', 'fin (ms)', 'debut (hh:mm:ss)', 'fin (hh:mm:ss)']
# ['Mot exact', 'qui', '', '', '', 'trés bien qui habitent la rue hein ?', 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'QB100', 97160.0, 98641.0, 0.001122685185185185, 0.001134259259259259]
# ['Mot exact', 'qui', '', '', '', 'qui habitent le ah bon ?', 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 370289.0, 371481.0, 0.004282407407407408, 0.004293981481481481]
# ['Mot exact', 'qui', '', '', '', 'quelles sont les choses qui vous plaisent le plus et les choses qui vous déplaisent ?', 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 734543.0, 738206.0, 0.00849537037037037, 0.008541666666666668]
# ['Mot exact', 'qui', '', '', '', "qu'est-ce que vous pensez des des femmes mariées qui travaillent ?", 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 768372.0, 772569.0, 0.008888888888888889, 0.008935185185185187]
# ['Mot exact', 'qui', '', '', '', 'alors à Orléans qui est-ce qui va à la maison de jeunes ?', 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 1062853.0, 1065278.0, 0.01229166666666667, 0.01232638888888889]
# ['Mot exact', 'qui', '', '', '', 'quelles sont les p- les personnes qui comptent les personnes importantes à Orléans ?', 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 1859247.0, 1864205.0, 0.0215162037037037, 0.02157407407407408]
# ['Mot exact', 'qui', '', '', '', "vous pouvez expliquer un peu ce qui s'est passé ?", 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 2026649.0, 2038217.0, 0.02344907407407407, 0.02358796296296296]
# ['Mot exact', 'qui', '', '', '', 'parmi vos vos connaissances quelle serait la personne qui parle le mieux français que vous connaissez enfin comme profession ?', 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 3569081.0, 3578155.0, 0.04130787037037037, 0.04141203703703704]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'à votre avis en France y a un organisme qui est chargé de décider si un mot fait ou une expression fait partie du français ou non ?", 'ESLO1_ENT_017', 'ESLO1_ENT_017_C', 'CS', 3847779.0, 3857143.0, 0.04452546296296297, 0.0446412037037037]
# ['Mot exact', 'qui', '', '', '', "et vous personnellement qu'est-ce que vous pensez de des femmes mariées qui travaillent enfin vous trouvez que c'est une bonne chose euh ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1139919.0, 1144385.0, 0.01318287037037037, 0.01324074074074074]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'il y a des professions qui vous semblent plus spécialement féminines ou bien est-ce que vous trouvez que ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1279241.0, 1283616.0, 0.01480324074074074, 0.01484953703703704]
# ['Mot exact', 'qui', '', '', '', 'il y a encore des professions qui ne demandent pas enfin une dépense uniquement physique euh ?', 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1317345.0, 1320876.0, 0.01524305555555556, 0.01527777777777778]
# ['Mot exact', 'qui', '', '', '', "en général c'est vous ou votre femme qui s'occupe de l'organisation des vacances ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1414283.0, 1418346.0, 0.01636574074074074, 0.01641203703703704]
# ['Mot exact', 'qui', '', '', '', "enfin c'est elle qui décide aussi par exemple de l'endroit o˘ vous passerez vos vacances ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1438347.0, 1441988.0, 0.01664351851851852, 0.01667824074074074]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'il y a des matiéres qui vous paraissent inutiles euh ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1590539.0, 1593008.0, 0.01840277777777778, 0.0184375]
# ['Mot exact', 'qui', '', '', '', "et est-ce qu'il y a des matiéres qui vous semblent ne pas être suffisamment développées à l'heure actuelle ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1704331.0, 1717361.0, 0.01972222222222222, 0.01987268518518518]
# ['Mot exact', 'qui', '', '', '', "et qu'est-ce que vous pensez des parents qui poussent leurs enfants enfin ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 1939500.0, 1942375.0, 0.02244212962962963, 0.02247685185185186]
# ['Mot exact', 'qui', '', '', '', 'qui poussent leurs enfants ?', 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'UF391', 1946125.0, 1947657.0, 0.02252314814814814, 0.02253472222222222]
# ['Mot exact', 'qui', '', '', '', "et comment vous expliquez qu'il y ait des enfants qui réussissent à l'école et d'autres pas ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 2249189.0, 2252485.0, 0.02603009259259259, 0.02606481481481481]
# ['Mot exact', 'qui', '', '', '', "entre celui qui voit l'ensemble du probléme enfin et le personnel qui ne voit que ?", 'ESLO1_ENT_018', 'ESLO1_ENT_018_C', 'BV', 3437246.0, 3442292.0, 0.03978009259259259, 0.03983796296296296]
# ['Mot exact', 'qui', '', '', '', "vous en avez d'autres qui sont moins bien élevés hein ?", 'ESLO1_ENT_019', 'ESLO1_ENT_019_C', 'UG393', 480961.0, 484282.0, 0.005555555555555556, 0.005601851851851852]
# ['Mot exact', 'qui', '', '', '', "mais pour l'éléve moyen alors qui n'a pas beaucoup de capacités académiques euh ?", 'ESLO1_ENT_019', 'ESLO1_ENT_019_C', 'JK', 676714.0, 682012.0, 0.007824074074074075, 0.007893518518518518]
# ['Mot exact', 'qui', '', '', '', "j'allais vous demander est-ce que vous pourriez m'expliquer un peu ce qui s'est passé ?", 'ESLO1_ENT_019', 'ESLO1_ENT_019_C', 'JK', 841996.0, 847457.0, 0.009733796296296298, 0.00980324074074074]
# ['Mot exact', 'qui', '', '', '', "quelle est la personne qui parle le mieux le français c'est-à-dire de quelle profession ?", 'ESLO1_ENT_019', 'ESLO1_ENT_019_C', 'JK', 2077143.0, 2090469.0, 0.02403935185185185, 0.02418981481481482]
# ['Mot exact', 'qui', '', '', '', 'y a-t-il en France euh un organisme officiel qui décide si un mot ou une expression fait partie ou non du bon français ?', 'ESLO1_ENT_019', 'ESLO1_ENT_019_C', 'JK', 2106289.0, 2118170.0, 0.024375, 0.02451388888888889]
# ['Mot exact', 'qui', '', '', '', 'et quelles sont les choses qui vous plaisent et les choses qui vous déplaisent ?', 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 108706.0, 112775.0, 0.00125, 0.001296296296296296]
# ['Mot exact', 'qui', '', '', '', "je veux dire quelles sont les personnes à Orléans qui comptent qui ont de l'importance à votre avis ?", 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 1160931.0, 1168571.0, 0.01342592592592592, 0.01351851851851852]
# ['Mot exact', 'qui', '', '', '', 'quel est le le la personne ou le type de profe- de profession qui selon vous parlerait le meilleur français ?', 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 2036641.0, 2047510.0, 0.02356481481481481, 0.02369212962962963]
# ['Mot exact', 'qui', '', '', '', "est-ce que vous vous pensez qu'il y a en France un organisme qui est chargé de décider si une expression ou un mot euh fait partie du français ou non ?", 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 2056097.0, 2066903.0, 0.0237962962962963, 0.02391203703703703]
# ['Mot exact', 'qui', '', '', '', "et si vous deviez euh dire quelque chose à quelqu'un qui qui à un ami qui habite euh à quelques kilométres trois quatre kilométres est-ce que vous vous déplaceriez ou vous écririez ?", 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 2293642.0, 2307156.0, 0.02653935185185185, 0.02670138888888889]
# ['Mot exact', 'qui', '', '', '', 'est-ce que dans la façon de parler de de votre femme y a des vous la reprenez des fois ou y a des choses que vous qui vous agacent un peu ?', 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 2746674.0, 2757501.0, 0.03178240740740741, 0.03190972222222222]
# ['Mot exact', 'qui', '', '', '', "qui est-ce qui reprend l'autre le plus souvent dans l'ensemble ?", 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 2775747.0, 2779064.0, 0.03211805555555556, 0.03216435185185185]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce qui reprenait votre pére ou votre mére surtout ?', 'ESLO1_ENT_020', 'ESLO1_ENT_020_C', 'CS', 2854673.0, 2857436.0, 0.03303240740740741, 0.03306712962962963]
# ['Mot exact', 'qui', '', '', '', "qu'est ce qui vous a amené à vivre ici ?", 'ESLO1_ENT_021', 'ESLO1_ENT_021_C', 'JK', 23139.0, 24858.0, 0.0002662037037037037, 0.0002777777777777778]
# ['Mot exact', 'qui', '', '', '', "il n'y a pas de chose qui vous déplait alors dans votre travail ?", 'ESLO1_ENT_021', 'ESLO1_ENT_021_C', 'JK', 217494.0, 221815.0, 0.002511574074074074, 0.002557870370370371]
# ['Mot exact', 'qui', '', '', '', "mais qui est-ce qui s'en sert le plus souvent maintenant ?", 'ESLO1_ENT_021', 'ESLO1_ENT_021_C', 'JK', 4474041.0, 4479016.0, 0.05178240740740741, 0.05184027777777778]
# ['Mot exact', 'qui', '', '', '', "qui d'entre vous avait la meilleure orthographe ou la plus belle écriture mettons ?", 'ESLO1_ENT_021', 'ESLO1_ENT_021_C', 'JK', 5815527.0, 5820988.0, 0.06730324074074073, 0.06736111111111111]
# ['Mot exact', 'qui', '', '', '', "dans le temps n'est-ce pas qui vous agaçaient dans le façon de parler de vos enfants ?", 'ESLO1_ENT_021', 'ESLO1_ENT_021_C', 'JK', 6134363.0, 6140209.0, 0.07099537037037036, 0.07106481481481482]
# ['Mot exact', 'qui', '', '', '', "et ce match ce mois de juin qui vient qu'est-ce vous ferez?", 'ESLO1_ENT_022', 'ESLO1_ENT_022_C', 'MD', 406456.0, 409300.0, 0.004699074074074074, 0.004733796296296296]
# ['Mot exact', 'qui', '', '', '', 'il y a des gens qui parlent pas bien ?', 'ESLO1_ENT_022', 'ESLO1_ENT_022_C', 'MD', 1343540.0, 1345187.0, 0.01554398148148148, 0.01556712962962963]
# ['Mot exact', 'qui', '', '', '', "qui est-ce qui s'en sert le plus souvent?", 'ESLO1_ENT_022', 'ESLO1_ENT_022_C', 'MD', 1714702.0, 1716319.0, 0.01983796296296296, 0.01986111111111111]
# ['Mot exact', 'qui', '', '', '', "c'est vous qui l'avez prise ?", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 503893.0, 505780.0, 0.005821759259259259, 0.005844907407407407]
# ['Mot exact', 'qui', '', '', '', "qu'est-ce que vous pensez du travail des des femmes c'est quelque chose qui vous parait euh normal ?", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 529674.0, 534165.0, 0.006122685185185185, 0.006180555555555556]
# ['Mot exact', 'qui', '', '', '', 'est-ce que parmi vos petits-enfants y en a qui font du latin par exemple euh ?', 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 867504.0, 872834.0, 0.01003472222222222, 0.01009259259259259]
# ['Mot exact', 'qui', '', '', '', 'qui sont arrivés ?', 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 1267255.0, 1267938.0, 0.01466435185185185, 0.01466435185185185]
# ['Mot exact', 'qui', '', '', '', "c'est un incendie qui était dû à quoi on sait pas ?", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 1297353.0, 1299772.0, 0.01501157407407407, 0.01503472222222222]
# ['Mot exact', 'qui', '', '', '', "des gens qui se qui ont beaucoup d'influence à Orléans ou qui sont trés importants dans la ville euh ?", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 1399133.0, 1405266.0, 0.01619212962962963, 0.01626157407407407]
# ['Mot exact', 'qui', '', '', '', 'qui comptent beaucoup ?', 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 1404457.0, 1405266.0, 0.01625, 0.01626157407407407]
# ['Mot exact', 'qui', '', '', '', 'sur le plan social ou sur le plan politique ou qui ménent qui ménent les affaires euh ?', 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 1409901.0, 1414356.0, 0.01630787037037037, 0.01636574074074074]
# ['Mot exact', 'qui', '', '', '', "qui avaient de l'influence jadis non ? ça ne ça n'existe presque plus", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 1449024.0, 1452947.0, 0.01677083333333333, 0.01680555555555556]
# ['Mot exact', 'qui', '', '', '', "et y a quelqu'un qui représente Jeanne d'Arc alors euh ?", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 1991136.0, 1993891.0, 0.02304398148148148, 0.02306712962962963]
# ['Mot exact', 'qui', '', '', '', "baratineur celui qui cause facilement on celui qui parle qui s'exprime bien ?", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'XZ501', 2830017.0, 2833141.0, 0.03275462962962963, 0.03278935185185185]
# ['Mot exact', 'qui', '', '', '', "autrement qui est-ce qui écrivait c'était vous ou votre femme ?", 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 3489741.0, 3491601.0, 0.04038194444444444, 0.04040509259259259]
# ['Mot exact', 'qui', '', '', '', 'euh y avait des choses qui vous agaçaient dans leur façon de parler ?', 'ESLO1_ENT_023', 'ESLO1_ENT_023_C', 'MB', 3569290.0, 3574212.0, 0.04130787037037037, 0.04136574074074074]
# ['Mot exact', 'qui', '', '', '', 'pour qui ?', 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 1134.0, 363890.0, 367167.0, 0.004201388888888889, 0.004247685185185185]
# ['Mot exact', 'qui', '', '', '', 'à votre travail enfin avec qui parlez-vous au cours de votre travail ?', 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 915678.0, 918835.0, 0.01059027777777778, 0.010625]
# ['Mot exact', 'qui', '', '', '', "et là je j'ai dit on mais on ça représente qui pour vous ?", 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 2496151.0, 2506892.0, 0.02888888888888889, 0.02900462962962963]
# ['Mot exact', 'qui', '', '', '', "est-ce que vous pourriez m'expliquer un peu ce qui s'est passé ?", 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 2603908.0, 2607705.0, 0.03012731481481482, 0.03017361111111111]
# ['Mot exact', 'qui', '', '', '', 'un étranger qui voudrait apprendre la langue française ?', 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 1134.0, 2712914.0, 2714846.0, 0.03138888888888889, 0.03141203703703704]
# ['Mot exact', 'qui', '', '', '', 'mais parmi les gens que vous connaissez quelle est la personne qui parle le mieux le français ?', 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 3562581.0, 3578794.0, 0.04122685185185185, 0.04141203703703704]
# ['Mot exact', 'qui', '', '', '', "et pour les papiers a- administratifs c'est vous qui les rempli- ou votre femme ?", 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 4105586.0, 4108882.0, 0.04751157407407407, 0.0475462962962963]
# ['Mot exact', 'qui', '', '', '', 'et qui de vous deux parle dans le meilleur français ?', 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 4188528.0, 4191352.0, 0.04847222222222222, 0.04850694444444444]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'il y a des choses qui vous agacent dans la façon de parler de votre femme ?", 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 4520884.0, 4530642.0, 0.05231481481481481, 0.05243055555555556]
# ['Mot exact', 'qui', '', '', '', "qui s'en sert le plus souvent ?", 'ESLO1_ENT_024', 'ESLO1_ENT_024_C', 'HM', 4670328.0, 4671430.0, 0.05405092592592593, 0.05406250000000001]
# ['Mot exact', 'qui', '', '', '', 'et il y avait des choses qui vous déplaisaient quand même ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 96926.0, 99322.0, 0.001111111111111111, 0.001145833333333333]
# ['Mot exact', 'qui', '', '', '', 'y a des choses qui vous agaçaient des fois ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 109677.0, 111437.0, 0.001261574074074074, 0.001284722222222222]
# ['Mot exact', 'qui', '', '', '', "qui voudrait d'un immeuble dans notre demeure ?", 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', '1135FEM', 428997.0, 431566.0, 0.004953703703703704, 0.004988425925925927]
# ['Mot exact', 'qui', '', '', '', 'et ça représente qui pour vous ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 616064.0, 618477.0, 0.007129629629629631, 0.007152777777777779]
# ['Mot exact', 'qui', '', '', '', "et vous croyez qu'il y a d'autres personnes qui y comptent ?", 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 625970.0, 630042.0, 0.007233796296296296, 0.007291666666666666]
# ['Mot exact', 'qui', '', '', '', "qui ont de l'influence ?", 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 629144.0, 630042.0, 0.007280092592592591, 0.007291666666666666]
# ['Mot exact', 'qui', '', '', '', "moi je n'étais pas en France à l'époque est-ce que vous pourriez m'expliquer un peu ce qui s'est passé ?", 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 648205.0, 653337.0, 0.007500000000000001, 0.00755787037037037]
# ['Mot exact', 'qui', '', '', '', "il n'y a pas des des gens qui ne parlent pas bien ?", 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 1059253.0, 1061403.0, 0.01225694444444444, 0.01228009259259259]
# ['Mot exact', 'qui', '', '', '', 'qui appartiennent à des milieux sociaux différents ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 1417348.0, 1420216.0, 0.01640046296296296, 0.01643518518518519]
# ['Mot exact', 'qui', '', '', '', 'quelle est la personne qui parle le mieux le français ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 1473743.0, 1477768.0, 0.01704861111111111, 0.01709490740740741]
# ['Mot exact', 'qui', '', '', '', 'qui de vous ou de votre femme écrit le plus souvent ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 1908080.0, 1912589.0, 0.02208333333333333, 0.02212962962962963]
# ['Mot exact', 'qui', '', '', '', "et qui c'est qui remplit les papiers administratifs ?", 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 1954931.0, 1957147.0, 0.02261574074074074, 0.02265046296296297]
# ['Mot exact', 'qui', '', '', '', 'y a-t-il des choses qui vous agacent dans la façon de parler de votre femme ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 2316672.0, 2320145.0, 0.02680555555555555, 0.02685185185185185]
# ['Mot exact', 'qui', '', '', '', 'y a-t-il des choses qui agacent votre femme dans la façon dont vous parlez ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 2333709.0, 2337356.0, 0.02700231481481481, 0.02704861111111111]
# ['Mot exact', 'qui', '', '', '', "l'un de vous qui reprend l'autre plus souvent ?", 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 2380266.0, 2382146.0, 0.02754629629629629, 0.02756944444444445]
# ['Mot exact', 'qui', '', '', '', 'euh y a-t-il des choses qui vous agacent dans la façon de parler de vos enfants ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 2404961.0, 2408159.0, 0.02782407407407407, 0.02787037037037037]
# ['Mot exact', 'qui', '', '', '', 'et qui le reprend le souvent le le plus souvent le leur pére ou leur mére ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 2431288.0, 2435827.0, 0.02813657407407407, 0.02818287037037037]
# ['Mot exact', 'qui', '', '', '', 'et vous les avez acheté tous ou il y en avait qui étaient c- des cadeaux ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 2766943.0, 2770979.0, 0.03201388888888889, 0.03206018518518518]
# ['Mot exact', 'qui', '', '', '', 'pour pour qui pour quoi ?', 'ESLO1_ENT_025', 'ESLO1_ENT_025_C', 'HM', 3029570.0, 3031307.0, 0.03505787037037037, 0.03508101851851852]
# ['Mot exact', 'qui', '', '', '', 'enfin certaines parties du du travail qui étaient plutôt des corvées que de que de plaisir ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 197427.0, 202602.0, 0.002280092592592593, 0.002337962962962963]
# ['Mot exact', 'qui', '', '', '', 'qui ne vont pas euh au collége au lycée enfin hein ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 1279215.0, 1282084.0, 0.01480324074074074, 0.01483796296296296]
# ['Mot exact', 'qui', '', '', '', 'qui sont en dessous du niveau alors les maintenir deux ans en étude comme ça ça donne pas grand-chose en général hein ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 1286129.0, 1292902.0, 0.01488425925925926, 0.01495370370370371]
# ['Mot exact', 'qui', '', '', '', "qui deviendra peut-être trés bien un jour ça c'est hein ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 1575782.0, 1578410.0, 0.01822916666666667, 0.01826388888888889]
# ['Mot exact', 'qui', '', '', '', "enfin d'autres personnes qui peuvent influer sur euh ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 1735385.0, 1738967.0, 0.02008101851851852, 0.02011574074074074]
# ['Mot exact', 'qui', '', '', '', "euh je n'étais pas en France à l'époque est-ce que vous pourriez m'expliquer ce qui s'est passé madame ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 1917126.0, 1922330.0, 0.0221875, 0.02224537037037037]
# ['Mot exact', 'qui', '', '', '', "alors celui qui représente le parti d'un monsieur dit moi je me désiste pour telle personne si vous suivez votre vote vous devez voter vous devez suivre vous comprenez ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 2379827.0, 2388842.0, 0.02753472222222222, 0.02763888888888889]
# ['Mot exact', 'qui', '', '', '', 'tous les Anglais ou autres qui viennent en France Allemands ou autres hein ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 2942817.0, 2957817.0, 0.03405092592592592, 0.03422453703703703]
# ['Mot exact', 'qui', '', '', '', 'oui dans les jeunes qui montent moi je crois que ça doit être mieux oui ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 3762493.0, 3771652.0, 0.04354166666666667, 0.04364583333333334]
# ['Mot exact', 'qui', '', '', '', 'et parmi vos connaissances madame quelle est la personne qui parle le meilleur français ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 3784156.0, 3788739.0, 0.0437962962962963, 0.04384259259259259]
# ['Mot exact', 'qui', '', '', '', "[pi:pronounce:instantaneous] qui faisait une euh licence de psychologie quand il m'écrivait il faisait des fautes eh ben je trouve ça laid je trouve ça je trouve pas ça hein ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 4471855.0, 4480874.0, 0.05174768518518519, 0.05185185185185185]
# ['Mot exact', 'qui', '', '', '', "d'une petite qui était en établissement hein ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 4547190.0, 4576209.0, 0.05262731481481481, 0.05296296296296296]
# ['Mot exact', 'qui', '', '', '', 'et qui de vous ou votre mari euh écrit habituellement aux amis communs ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 4647271.0, 4651927.0, 0.05378472222222222, 0.05383101851851851]
# ['Mot exact', 'qui', '', '', '', 'et qui de vous euh ou de votre mari posséde la meilleure orthographe ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 4774012.0, 4778529.0, 0.05525462962962963, 0.05530092592592593]
# ['Mot exact', 'qui', '', '', '', 'et y a-t-il des choses qui vous agacent dans la façon de parler de votre mari ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 5161987.0, 5166004.0, 0.0597337962962963, 0.05979166666666667]
# ['Mot exact', 'qui', '', '', '', 'et y a-t-il des choses qui vous agacent dans la façon de parler de vos enfants ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 5208791.0, 5213561.0, 0.06027777777777778, 0.06033564814814815]
# ['Mot exact', 'qui', '', '', '', "euh et qui est-ce qui reprend les enfants le plus souvent c'est vous ou leur pére ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 5336483.0, 5342374.0, 0.06175925925925926, 0.06182870370370371]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce qui vous reprenait le plus souvent votre pére ou votre mére ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 5383619.0, 5387294.0, 0.06230324074074074, 0.06234953703703704]
# ['Mot exact', 'qui', '', '', '', "qui s'en sert ?", 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 'JSM', 5736496.0, 5737168.0, 0.06638888888888889, 0.06640046296296297]
# ['Mot exact', 'qui', '', '', '', 'y a des personnes qui ne savent pas hein ?', 'ESLO1_ENT_026', 'ESLO1_ENT_026_C', 1254.0, 5898246.0, 5900664.0, 0.06826388888888889, 0.06828703703703703]
# ['Mot exact', 'qui', '', '', '', 'il y a des choses qui qui vous plaisent et qui vous déplaisent ?', 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 'HM', 117402.0, 121842.0, 0.001354166666666667, 0.001400462962962963]
# ['Mot exact', 'qui', '', '', '', 'qui on ?', 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 1299.0, 1013571.0, 1018288.0, 0.01172453703703704, 0.01178240740740741]
# ['Mot exact', 'qui', '', '', '', 'qui ?', 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 'HM', 1046952.0, 1047171.0, 0.01210648148148148, 0.01211805555555556]
# ['Mot exact', 'qui', '', '', '', "ce qui s'est passé ?", 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 'HM', 1077150.0, 1078787.0, 0.01246527777777778, 0.01247685185185185]
# ['Mot exact', 'qui', '', '', '', "alors il n'y a pas de gens à Orléans qui ne parlent pas bien enfin ?", 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 'HM', 1541852.0, 1545982.0, 0.01783564814814815, 0.01788194444444444]
# ['Mot exact', 'qui', '', '', '', 'et parmi vos connaissances quelle est la personne qui parle le mieux le français ?', 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 'HM', 2074062.0, 2077835.0, 0.02400462962962963, 0.02403935185185185]
# ['Mot exact', 'qui', '', '', '', 'y a-t-il en France un organisme qui décide si un mot ou une expression fait partie ou non du du bon français ?', 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 'HM', 2107044.0, 2114243.0, 0.02438657407407407, 0.02446759259259259]
# ['Mot exact', 'qui', '', '', '', "qui s'appelait ?", 'ESLO1_ENT_027', 'ESLO1_ENT_027_C', 'HM', 3006028.0, 3006685.0, 0.03479166666666667, 0.03479166666666667]
# ['Mot exact', 'qui', '', '', '', 'il y a quelque chose qui vous plairait ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 168488.0, 170039.0, 0.001944444444444444, 0.001967592592592593]
# ['Mot exact', 'qui', '', '', '', 'bah y a pas des matiéres qui vous semblent plus importantes ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 420615.0, 427732.0, 0.004861111111111111, 0.004942129629629629]
# ['Mot exact', 'qui', '', '', '', 'mais on ça représente qui pour vous ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 782962.0, 785687.0, 0.009050925925925926, 0.009085648148148148]
# ['Mot exact', 'qui', '', '', '', "y a autres d'autres personnes qui qui comptent qui ont de l'influence ?", 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 804838.0, 824197.0, 0.009305555555555555, 0.009537037037037037]
# ['Mot exact', 'qui', '', '', '', "si ce qui s'est passé ?", 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 837211.0, 838379.0, 0.0096875, 0.009699074074074074]
# ['Mot exact', 'qui', '', '', '', 'peut-être des amis qui ont été plus touchés par les événements non ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 887952.0, 891778.0, 0.0102662037037037, 0.0103125]
# ['Mot exact', 'qui', '', '', '', "qui est d'une classe différente ?", 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 969607.0, 992505.0, 0.01121527777777778, 0.01148148148148148]
# ['Mot exact', 'qui', '', '', '', 'qui alors ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 1245716.0, 1254657.0, 0.01440972222222222, 0.01451388888888889]
# ['Mot exact', 'qui', '', '', '', 'est-ce qui y a des gens qui ne parlent parlent pas bien ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 1335566.0, 1337776.0, 0.01545138888888889, 0.01547453703703704]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 948.0, 1466041.0, 1467377.0, 0.01696759259259259, 0.01697916666666667]
# ['Mot exact', 'qui', '', '', '', 'euh quelle est la personne qui parle le mieux le français ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 1788375.0, 1803070.0, 0.02069444444444445, 0.02086805555555556]
# ['Mot exact', 'qui', '', '', '', 'un organisme qui décide si un mot ou une expression fait partie ou non du bon français ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 1840353.0, 1845772.0, 0.0212962962962963, 0.02135416666666666]
# ['Mot exact', 'qui', '', '', '', 'qui de vous ou de votre mari écrit habituellement aux amis communs ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 2188451.0, 2192667.0, 0.02532407407407408, 0.02537037037037037]
# ['Mot exact', 'qui', '', '', '', "qui c'est qui remplit les papiers administratifs ?", 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 2243569.0, 2245719.0, 0.02596064814814815, 0.0259837962962963]
# ['Mot exact', 'qui', '', '', '', 'et qui de vous ou de votre mari posséde la meilleure orth-orthographe ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 2290398.0, 2294973.0, 0.02650462962962963, 0.02655092592592593]
# ['Mot exact', 'qui', '', '', '', "euh là je ne cherche pas à vous offenser monsieur est-ce qu'il y a des choses qui vous agacent dans la façon de parler de votre mari ?", 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 2575744.0, 2581852.0, 0.02980324074074074, 0.02987268518518518]
# ['Mot exact', 'qui', '', '', '', 'qui vous reprenait le plus souvent votre pére ou votre mére ?', 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 2647099.0, 2649937.0, 0.03063657407407408, 0.03065972222222222]
# ['Mot exact', 'qui', '', '', '', "et qui s'en sert le plus souvent ?", 'ESLO1_ENT_028', 'ESLO1_ENT_028_C', 'HM', 2778369.0, 2780129.0, 0.03215277777777777, 0.03217592592592593]
# ['Mot exact', 'qui', '', '', '', 'et on ça représente qui ?', 'ESLO1_ENT_029', 'ESLO1_ENT_029_C', 'JSM', 1761126.0, 1762497.0, 0.02038194444444445, 0.02039351851851852]
# ['Mot exact', 'qui', '', '', '', 'une que- enfin une derniére question sur ce questionnaire qui est est-ce que les différences entre les classes ont tendance à diminuer ou à augmenter ?', 'ESLO1_ENT_029', 'ESLO1_ENT_029_C', 'JSM', 3261472.0, 3268113.0, 0.03774305555555556, 0.03782407407407407]
# ['Mot exact', 'qui', '', '', '', 'et parmi vos connaissances quelle est la personne qui parle le mieux le français ?', 'ESLO1_ENT_029', 'ESLO1_ENT_029_C', 'JSM', 4587069.0, 4590776.0, 0.05309027777777778, 0.053125]
# ['Mot exact', 'qui', '', '', '', 'et y a-t-il en France un organisme qui décide si un mot ou une expression fait partie ou non du bon français ?', 'ESLO1_ENT_029', 'ESLO1_ENT_029_C', 'JSM', 4623724.0, 4630132.0, 0.05350694444444445, 0.05358796296296297]
# ['Mot exact', 'qui', '', '', '', 'et qui est-ce qui vous reprenait le plus souvent votre pére ou votre mére ?', 'ESLO1_ENT_029', 'ESLO1_ENT_029_C', 'JSM', 5329576.0, 5332833.0, 0.06167824074074074, 0.06171296296296296]
# ['Mot exact', 'qui', '', '', '', "entre euh les éléves par exemple qui viennent de CEG de CES ou d'un lycée ?", 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 1478744.0, 1489716.0, 0.01710648148148148, 0.0172337962962963]
# ['Mot exact', 'qui', '', '', '', "vous voyez-vous d'autres personnes par exemple qui ont de l'influence à part le conseil municipal ou le maire ?", 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 1722127.0, 1730172.0, 0.01993055555555556, 0.02002314814814815]
# ['Mot exact', 'qui', '', '', '', "est-ce que vous pourriez m'expliquer un peu ce qui s'est passé ?", 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 1752074.0, 1760957.0, 0.02027777777777778, 0.02037037037037037]
# ['Mot exact', 'qui', '', '', '', "à quoi est-ce qu'on reconnait euh des gens qui appartiennent aux classes aisées par exemple ?", 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 1930871.0, 1946778.0, 0.02233796296296296, 0.02252314814814814]
# ['Mot exact', 'qui', '', '', '', 'qui devraient être évités en France ?', 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 4001.0, 2125977.0, 2127444.0, 0.02459490740740741, 0.02461805555555556]
# ['Mot exact', 'qui', '', '', '', 'et parmi vos connaissances quelle est la personne qui parle mieux le mieux le français ?', 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 3126555.0, 3139325.0, 0.03618055555555556, 0.03633101851851852]
# ['Mot exact', 'qui', '', '', '', 'la personne qui parle le mieux le français vous voyez pas une personne euh ? je sais pas', 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 3162673.0, 3167882.0, 0.03659722222222223, 0.03665509259259259]
# ['Mot exact', 'qui', '', '', '', 'et y a-til un a- euh en France un organisme qui décide si un mot ou une expression fait partie ou non du bon français ?', 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 3197209.0, 3205758.0, 0.03700231481481481, 0.0370949074074074]
# ['Mot exact', 'qui', '', '', '', 'euh y a-t-il des choses qui vous agacent dans la façon de parler de vos enfants ?', 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 4584839.0, 4599416.0, 0.05305555555555556, 0.05322916666666666]
# ['Mot exact', 'qui', '', '', '', "il n'y a pas de fautes qui vous agacent ?", 'ESLO1_ENT_030', 'ESLO1_ENT_030_C', 'JSM', 4597159.0, 4599416.0, 0.05320601851851852, 0.05322916666666666]
# ['Mot exact', 'qui', '', '', '', 'avec qui est-ce que est-ce que vous parlez au cours de de votre travail enfin de de ménagére ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 259755.0, 266669.0, 0.002997685185185185, 0.003078703703703704]
# ['Mot exact', 'qui', '', '', '', 'avec qui euh ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 276906.0, 277982.0, 0.003194444444444444, 0.003206018518518519]
# ['Mot exact', 'qui', '', '', '', "dans dans vos activités n'est-ce pas quel genre de gens euh avec quel genre de personnes avec qui vous parlez ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 285347.0, 299671.0, 0.003298611111111111, 0.003460648148148148]
# ['Mot exact', 'qui', '', '', '', 'mais celles celles qui vont venir ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 425962.0, 426967.0, 0.004918981481481482, 0.004930555555555555]
# ['Mot exact', 'qui', '', '', '', 'vous ne trouvez pas ? ceux qui peuvent continuer', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 585495.0, 587045.0, 0.006770833333333334, 0.006793981481481482]
# ['Mot exact', 'qui', '', '', '', 'à qui est-ce que vous pensez ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 658083.0, 659264.0, 0.007615740740740741, 0.007627314814814815]
# ['Mot exact', 'qui', '', '', '', "et est-ce qu'y a des des personnes qui comptent à Orléans ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 683364.0, 686875.0, 0.007905092592592592, 0.007939814814814814]
# ['Mot exact', 'qui', '', '', '', 'euh qui comptent point de vue financier ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 686875.0, 688747.0, 0.007939814814814814, 0.007962962962962963]
# ['Mot exact', 'qui', '', '', '', "comptent euh qui ont de l'influence ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 689181.0, 691062.0, 0.007974537037037037, 0.007997685185185186]
# ['Mot exact', 'qui', '', '', '', "ah qui ont de l'influence ? pardon", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 691062.0, 695034.0, 0.007997685185185186, 0.008043981481481482]
# ['Mot exact', 'qui', '', '', '', 'qui seraient ces personnes à votre avis ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 697482.0, 700605.0, 0.00806712962962963, 0.008101851851851851]
# ['Mot exact', 'qui', '', '', '', 'euh euh qui comptent euh mais pour quoi pour euh ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 700605.0, 705671.0, 0.008101851851851851, 0.008159722222222223]
# ['Mot exact', 'qui', '', '', '', "mais v- pour s- pour ce que vous pensez enfin qui est pou- pour pour ce qui est important pour vous n'est-ce pas ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 705671.0, 710334.0, 0.008159722222222223, 0.008217592592592594]
# ['Mot exact', 'qui', '', '', '', 'ce qui est important ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 710334.0, 713218.0, 0.008217592592592594, 0.008252314814814815]
# ['Mot exact', 'qui', '', '', '', "quelles seraient les personnes qui euh à votre avis ont de l'in- ont de l'influence à Orléans ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 713218.0, 718495.0, 0.008252314814814815, 0.008310185185185186]
# ['Mot exact', 'qui', '', '', '', "est-ce que vous pourriez m'expliquer ce qui s'est passé selon selon vous ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 737117.0, 740295.0, 0.008530092592592593, 0.008564814814814815]
# ['Mot exact', 'qui', '', '', '', "et euh à votre avis comment est-ce qu'on peut expliquer ce qui s'est passé ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 780998.0, 788336.0, 0.009027777777777779, 0.00912037037037037]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'il y a un parti euh politique qui représente vos opinions ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 796491.0, 799860.0, 0.009212962962962963, 0.009247685185185185]
# ['Mot exact', 'qui', '', '', '', "euh qui s'en sert le plus souvent de ces dictionnaires ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 1099682.0, 1102211.0, 0.01271990740740741, 0.01275462962962963]
# ['Mot exact', 'qui', '', '', '', "euh le journal que que vous lisez habituellement est-ce qui euh est-ce qu'il est-ce qu'il parle de la langue française euh est-ce qu'y a une rubrique sur la langue française dans votre journal vous ne savez pas ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 1300332.0, 1309850.0, 0.0150462962962963, 0.01515046296296296]
# ['Mot exact', 'qui', '', '', '', "y a d'autres mots qui euh qui vous ont frappée comme ça enfin des mots anglais en français ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 1434338.0, 1442060.0, 0.01659722222222222, 0.01668981481481482]
# ['Mot exact', 'qui', '', '', '', 'entre les gens qui appartiennent à des différents milieux ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 1451060.0, 1454023.0, 0.01679398148148148, 0.0168287037037037]
# ['Mot exact', 'qui', '', '', '', 'comment dirais-je ? par exemple le midi par exemple on n- y a beaucoup de gens qui disent le midi ça ne se dit pas', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 1495881.0, 1501007.0, 0.01730324074074074, 0.01737268518518519]
# ['Mot exact', 'qui', '', '', '', "que je dis qui qui je ne sais pas qu'il faudrait pas que vous comprenez ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 1561404.0, 1564850.0, 0.01806712962962963, 0.01810185185185185]
# ['Mot exact', 'qui', '', '', '', "et est-ce qu'il y a en France un organisme qui décide si un mot ou une expression fait partie ou non du du son français euh ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 1645316.0, 1654160.0, 0.01903935185185185, 0.01914351851851852]
# ['Mot exact', 'qui', '', '', '', "qu'y ait d'organisme qui décide oui ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 1656842.0, 1658686.0, 0.01916666666666667, 0.01918981481481482]
# ['Mot exact', 'qui', '', '', '', 'habituellement euh qui de vous ou de votre mari écrit euh aux amis par exemple ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2010576.0, 2015851.0, 0.02326388888888889, 0.02332175925925926]
# ['Mot exact', 'qui', '', '', '', "et alors d'un de votre côté évidemment ils sont pas à Orléans et qui est-ce qui écrit euh ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2053671.0, 2058783.0, 0.02376157407407407, 0.02381944444444445]
# ['Mot exact', 'qui', '', '', '', 'et qui est-ce qui parle dans le meilleur français vous ou votre mari ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2136371.0, 2139170.0, 0.02472222222222223, 0.02475694444444444]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'y a des choses qui vous agacent dans la façon de parler de votre mari ? je m'excuse de vous poser des questions indiscrétes mais", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2363826.0, 2369092.0, 0.02734953703703704, 0.02741898148148149]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'y a des choses qui qui vous agacent euh enfin ou que vous n'aimez pas dans la façon de parler de vos enfants ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2491063.0, 2499075.0, 0.02883101851851852, 0.02892361111111111]
# ['Mot exact', 'qui', '', '', '', 'qui vous agacent ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2506883.0, 2508824.0, 0.02900462962962963, 0.02902777777777778]
# ['Mot exact', 'qui', '', '', '', "qui est-ce qui vous a élevée c'est peut-être une ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2607348.0, 2608758.0, 0.03017361111111111, 0.03018518518518519]
# ['Mot exact', 'qui', '', '', '', 'mais euh en ce qui vous concerne ? est-ce', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2654425.0, 2656860.0, 0.03071759259259259, 0.03074074074074074]
# ['Mot exact', 'qui', '', '', '', 'en ce qui me concerne ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 2656860.0, 2658383.0, 0.03074074074074074, 0.03076388888888889]
# ['Mot exact', 'qui', '', '', '', 'de la famille qui ont fait et qui font ou bien qui feront du latin ? est-ce que vous savez euh ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 2999338.0, 3004692.0, 0.03471064814814815, 0.03476851851851852]
# ['Mot exact', 'qui', '', '', '', 'ah qui ont fait ? oh ben oui', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'BB733', 3004692.0, 3006221.0, 0.03476851851851852, 0.03479166666666667]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'y a des membres de votre famille qui qui ont fait qui font ou qui feront leurs études dans un établissement privé ? euh libre ?", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 3029072.0, 3036088.0, 0.03505787037037037, 0.03513888888888889]
# ['Mot exact', 'qui', '', '', '', "ah ben tiens une question qu'on a que j'ai déjà demandée je peux la répéter est-ce qu'il y a un parti politique qui représente bien vos opinions ? euh", 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 3664549.0, 3672068.0, 0.0424074074074074, 0.0425]
# ['Mot exact', 'qui', '', '', '', 'qui représente bien vos opinions euh ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 3673848.0, 3677792.0, 0.04251157407407408, 0.04255787037037037]
# ['Mot exact', 'qui', '', '', '', 'enfin y a vous ne vous ne voyez pas de parti euh particulier qui représente vraiment ce que vous pensez ? pour qui vous voteriez sans sans réserve euh ?', 'ESLO1_ENT_041', 'ESLO1_ENT_041_C', 'MB', 3687216.0, 3694898.0, 0.04267361111111111, 0.04275462962962964]
# ['Mot exact', 'qui', '', '', '', "euh tout à l'heure on disait on enfin est-ce qu'on a fait assez pour les habitants à Orléans on pour vous c'est qui enfin ?", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 1094169.0, 1099321.0, 0.01266203703703704, 0.01271990740740741]
# ['Mot exact', 'qui', '', '', '', "justement est-ce qu'il y a des personnes qui comptent à Orléans ? enfin qui ont de l'influence", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 1170163.0, 1175223.0, 0.01354166666666667, 0.01359953703703704]
# ['Mot exact', 'qui', '', '', '', "moi je n'étais pas en France à cette époque est-ce que vous pourriez m'expliquer ce qui s'est passé ?", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 1231089.0, 1235625.0, 0.01424768518518518, 0.01429398148148148]
# ['Mot exact', 'qui', '', '', '', 'qui sait ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BC709', 1331873.0, 1337367.0, 0.01540509259259259, 0.01547453703703704]
# ['Mot exact', 'qui', '', '', '', 'qui était aux enfants aussi ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 1868027.0, 1869372.0, 0.02162037037037037, 0.02163194444444444]
# ['Mot exact', 'qui', '', '', '', 'et qui se sert le plus souvent des dictionnaires ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 1893087.0, 1897070.0, 0.02190972222222222, 0.02195601851851852]
# ['Mot exact', 'qui', '', '', '', 'dans la façon de parler le français entre des gens qui appartiennent à des milieux sociaux différents ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 2290996.0, 2297920.0, 0.02650462962962963, 0.02658564814814815]
# ['Mot exact', 'qui', '', '', '', 'et parmi vos connaissances quelle est la personne qui parle le mieux le français ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 2431213.0, 2436040.0, 0.02813657407407407, 0.02819444444444444]
# ['Mot exact', 'qui', '', '', '', "sur Orléans ? quelqu'un qui qui a un vocabulaire euh trés précieux trés ?", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BC709', 2475733.0, 2480388.0, 0.02864583333333333, 0.0287037037037037]
# ['Mot exact', 'qui', '', '', '', "est-ce qu'il y a en France un organisme qui décide si un mot ou une expression fait partie ou non du bon français ?", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 2502109.0, 2506669.0, 0.02895833333333334, 0.02900462962962963]
# ['Mot exact', 'qui', '', '', '', "et si cette personne est est quelqu'un qui vous est supérieur euh ?", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3194719.0, 3199904.0, 0.03696759259259259, 0.03702546296296296]
# ['Mot exact', 'qui', '', '', '', "et à qui faut que j'écrive ?", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BC709', 3199904.0, 3201244.0, 0.03702546296296296, 0.03704861111111111]
# ['Mot exact', 'qui', '', '', '', 'qui écrit habituellement de vous ou de votre mari à vos amis communs ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3494553.0, 3498636.0, 0.04043981481481482, 0.0404861111111111]
# ['Mot exact', 'qui', '', '', '', 'qui écrit ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3514363.0, 3515942.0, 0.0406712962962963, 0.04068287037037038]
# ['Mot exact', 'qui', '', '', '', "enfin ça n'est pas votre mari qui qui lui écrit ?", 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3530199.0, 3532469.0, 0.04085648148148149, 0.04087962962962963]
# ['Mot exact', 'qui', '', '', '', 'et qui remplit les papiers administratifs ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3566643.0, 3569676.0, 0.04127314814814815, 0.04130787037037037]
# ['Mot exact', 'qui', '', '', '', 'qui de vous ou de votre mari posséde la meilleure orthographe ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3608980.0, 3612490.0, 0.04175925925925925, 0.04180555555555556]
# ['Mot exact', 'qui', '', '', '', 'qui parle dans le meilleur français ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3627930.0, 3632775.0, 0.04197916666666667, 0.04203703703703704]
# ['Mot exact', 'qui', '', '', '', 'et qui écrit dans le meilleur français ?', 'ESLO1_ENT_042', 'ESLO1_ENT_042_C', 'BV', 3674992.0, 3679013.0, 0.04252314814814815, 0.04258101851851852]
# ['Mot exact', 'qui', '', '', '', 'qui vient ici ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 93563.0, 94219.0, 0.001076388888888889, 0.001087962962962963]
# ['Mot exact', 'qui', '', '', '', 'y a quelque chose qui vous plaît ou qui vous déplaît dans votre travail ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 132234.0, 136359.0, 0.001527777777777778, 0.001574074074074074]
# ['Mot exact', 'qui', '', '', '', 'ça ça représente qui ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 470152.0, 478010.0, 0.005439814814814815, 0.005532407407407407]
# ['Mot exact', 'qui', '', '', '', 'ça représente qui ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 489258.0, 494961.0, 0.005659722222222222, 0.005717592592592593]
# ['Mot exact', 'qui', '', '', '', "est-ce que il y a d'autres personnes qui comptent enfin qui ont de l'influence à Orléans ?", 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 543147.0, 551038.0, 0.006284722222222223, 0.006377314814814815]
# ['Mot exact', 'qui', '', '', '', 'euh qui donc ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 584335.0, 586429.0, 0.006759259259259259, 0.006782407407407408]
# ['Mot exact', 'qui', '', '', '', "y a d'autre personne qui ont de l'influence alors ?", 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 603194.0, 605725.0, 0.006979166666666667, 0.007002314814814815]
# ['Mot exact', 'qui', '', '', '', "euh est-ce que vous pourriez m'expliquer ce qui c'est passé briévement ?", 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 619443.0, 623724.0, 0.007164351851851851, 0.007210648148148147]
# ['Mot exact', 'qui', '', '', '', "mais c'était un cadeau de qui ?", 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 850519.0, 853457.0, 0.009837962962962963, 0.009872685185185186]
# ['Mot exact', 'qui', '', '', '', "qui s'en sert le plus souvent ?", 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 873879.0, 875848.0, 0.01010416666666667, 0.01012731481481481]
# ['Mot exact', 'qui', '', '', '', 'qui dont ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 1335551.0, 1336051.0, 0.01545138888888889, 0.01546296296296296]
# ['Mot exact', 'qui', '', '', '', 'qui sont meilleurs ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 1447020.0, 1447754.0, 0.01674768518518518, 0.01674768518518518]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce qui remplit les papiers administratifs ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 1808753.0, 1811097.0, 0.02092592592592593, 0.02096064814814815]
# ['Mot exact', 'qui', '', '', '', 'euh qui est-ce qui parle dans le meilleur français ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 1867829.0, 1870423.0, 0.0216087962962963, 0.02164351851851852]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce qui écrit dans le meilleur français ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 1880356.0, 1882497.0, 0.02175925925925926, 0.02178240740740741]
# ['Mot exact', 'qui', '', '', '', 'qui vous reprenait à ce moment-là ?', 'ESLO1_ENT_043', 'ESLO1_ENT_043_C', 'DP', 2634444.0, 2636241.0, 0.03048611111111111, 0.03050925925925926]
# ['Mot exact', 'qui', '', '', '', 'parlent le français les gens qui appartiennent à des des des classes différentes ?', 'ESLO1_ENT_044', 'ESLO1_ENT_044_C', 'OU', 1158716.0, 1167623.0, 0.01340277777777778, 0.01350694444444444]
# ['Mot exact', 'qui', '', '', '', "et en quoi enfin qu'est-ce que c'est qu'est-ce que c'est qui fait la différence ?", 'ESLO1_ENT_044', 'ESLO1_ENT_044_C', 'OU', 1181435.0, 1187103.0, 0.01366898148148148, 0.01373842592592593]
# ['Mot exact', 'qui', '', '', '', 'est-ce que vous connaissez des gens qui parlent enfin spécialement bien ?', 'ESLO1_ENT_044', 'ESLO1_ENT_044_C', 'OU', 1272662.0, 1278641.0, 0.01472222222222222, 0.01479166666666667]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce qui parle bien le copain ou le pére ?', 'ESLO1_ENT_044', 'ESLO1_ENT_044_C', 'OU', 1290029.0, 1293345.0, 0.01493055555555556, 0.01496527777777778]
# ['Mot exact', 'qui', '', '', '', "mais à qui est-ce que vous pensiez d'abord vous pensiez à votre copain ?", 'ESLO1_ENT_044', 'ESLO1_ENT_044_C', 'OU', 1300678.0, 1303155.0, 0.0150462962962963, 0.01508101851851852]
# ['Mot exact', 'qui', '', '', '', 'un organisme qui décide si un mot fait partie du bon français ou non ?', 'ESLO1_ENT_044', 'ESLO1_ENT_044_C', 'OU', 1332620.0, 1339721.0, 0.01541666666666667, 0.01549768518518519]
# ...
# ['Mot exact', 'qui', '', '', '', "c'est qui ?", 'ESLO2_ECOLE_1296', 'ESLO2_ECOLE_1296_C', 'ELEV_CM2', 5871956.0, 5872766.0, 0.0679513888888889, 0.06796296296296296]
# ['Mot exact', 'qui', '', '', '', "c'est qui ?", 'ESLO2_ECOLE_1296', 'ESLO2_ECOLE_1296_C', 'ELEV_CM2', 5892676.0, 5893661.0, 0.06819444444444445, 0.06820601851851853]
# ['Mot exact', 'qui', '', '', '', "c'est qui ?", 'ESLO2_ECOLE_1296', 'ESLO2_ECOLE_1296_C', 'ELEV_CM2', 5898694.0, 5899691.0, 0.06826388888888889, 0.06827546296296295]
# ['Mot exact', 'qui', '', '', '', "c'est qui qui a fait ça ?", 'ESLO2_ECOLE_1296', 'ESLO2_ECOLE_1296_C', 'ELEV_CM2', 5899691.0, 5900950.0, 0.06827546296296295, 0.06828703703703703]
# ['Mot exact', 'qui', '', '', '', "c'est qui ?", 'ESLO2_ECOLE_1296', 'ESLO2_ECOLE_1296_C', 'ELEV_CM2', 5960664.0, 5961524.0, 0.06898148148148148, 0.06899305555555556]
# ['Mot exact', 'qui', '', '', '', "mais non mais c'est qui c'est qui Philippe le loup ?", 'ESLO2_ECOLE_1296', 'ESLO2_ECOLE_1296_C', 'ELEV_CM2', 6282167.0, 6290546.0, 0.07270833333333333, 0.07280092592592592]
# ['Mot exact', 'qui', '', '', '', 'qui ici fait du soutien ?', 'ESLO2_ECOLE_1297', 'ESLO2_ECOLE_1297_C', 'ELEV_CM2', 2199750.0, 2209954.0, 0.02545138888888889, 0.02556712962962963]
# ['Mot exact', 'qui', '', '', '', 'qui veut jouer à tu me tiens je te tiens la barbichette avec moi ?', 'ESLO2_ECOLE_1297', 'ESLO2_ECOLE_1297_C', 'ELEV_CM2', 2880436.0, 2882852.0, 0.03333333333333333, 0.03335648148148148]
# ['Mot exact', 'qui', '', '', '', 'qui veut jouer avec moi ?', 'ESLO2_ECOLE_1297', 'ESLO2_ECOLE_1297_C', 'ELEV_CM2', 2936315.0, 2954345.0, 0.03398148148148148, 0.03418981481481482]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce qui rejoue ?', 'ESLO2_ECOLE_1298', 'ESLO2_ECOLE_1298_C', 'ELEV_CM2', 133981.0, 140017.0, 0.001539351851851852, 0.00162037037037037]
# ['Mot exact', 'qui', '', '', '', 'je suis avec qui ?', 'ESLO2_ECOLE_1298', 'ESLO2_ECOLE_1298_C', 'ELEV_CM2', 2056802.0, 2063870.0, 0.0237962962962963, 0.02387731481481481]
# ['Mot exact', 'qui', '', '', '', 'Arthur qui ?', 'ESLO2_ECOLE_1299', 'ESLO2_ECOLE_1299_C', 'ELEV_CM2', 206337.0, 207774.0, 0.002384259259259259, 0.002395833333333334]
# ['Mot exact', 'qui', '', '', '', 'il nous manque qui ?', 'ESLO2_ECOLE_1299', 'ESLO2_ECOLE_1299_C', 'PROF_Philippe', 412939.0, 413538.0, 0.004768518518518518, 0.004780092592592592]
# ['Mot exact', 'qui', '', '', '', 'tu es qui toi ?', 'ESLO2_ECOLE_1299', 'ESLO2_ECOLE_1299_C', 'ELEV_CM2', 483412.0, 484035.0, 0.005590277777777778, 0.005601851851851852]
# ['Mot exact', 'qui', '', '', '', 'qui a roté ?', 'ESLO2_ECOLE_1299', 'ESLO2_ECOLE_1299_C', 'ELEV_CM2', 1438016.0, 1438914.0, 0.01664351851851852, 0.01664351851851852]
# ['Mot exact', 'qui', '', '', '', 'qui il ?', 'ESLO2_ECOLE_1299', 'ESLO2_ECOLE_1299_C', 'PROF_Philippe', 1989204.0, 1990665.0, 0.02302083333333333, 0.0230324074074074]
# ['Mot exact', 'qui', '', '', '', 'qui est-ce ?', 'ESLO2_LIVRENF_1306', 'ESLO2_LIVRENF_1306_C', 'LEC_HX853', 24882.0, 27658.0, 0.0002777777777777778, 0.0003125]
# ['Mot exact', 'qui', '', '', '', "ah c'est qui ?", 'ESLO2_LIVRENF_1311', 'ESLO2_LIVRENF_1311_C', 'LEC_MC019', 278841.0, 318772.0, 0.003217592592592593, 0.003680555555555555]
# ['Mot exact', 'qui', '', '', '', 'qui ?', 'ESLO2_LIVRENF_1311', 'ESLO2_LIVRENF_1311_C', 'ENF_XH006', 554738.0, 555592.0, 0.006412037037037036, 0.006423611111111112]
# ['Mot exact', 'qui', '', '', '', "c'est qui Grignotin c'est la marmotte?", 'ESLO2_LIVRENF_1311', 'ESLO2_LIVRENF_1311_C', 'LEC_MC019', 638286.0, 640014.0, 0.00738425925925926, 0.007407407407407407]
# ['Mot exact', 'qui', '', '', '', "c'est pas toi qui va me coucher ?", 'ESLO2_LIVRENF_1311', 'ESLO2_LIVRENF_1311_C', 'ENF_XH006', 1066445.0, 1068033.0, 0.01233796296296296, 0.01236111111111111]
# ['Mot exact', 'qui', '', '', '', "c'est qui ça c'est la maîtresse ?", 'ESLO2_LIVRENF_1312', 'ESLO2_LIVRENF_1312_C', 'LEC_ZD381', 309542.0, 311245.0, 0.003576388888888889, 0.003599537037037037]
# ['Mot exact', 'qui', '', '', '', "c'est toi qui as fait s- un rototo ?", 'ESLO2_LIVRENF_1313', 'ESLO2_LIVRENF_1313_C', 'LEC_BV405', 169207.0, 357090.0, 0.001956018518518518, 0.004131944444444444]
# ['Mot exact', 'qui', '', '', '', 'hé hé ho pour qui tu te prends Loudoudou ?', 'ESLO2_LIVRENF_1313', 'ESLO2_LIVRENF_1313_C', 'LEC_BV405', 198215.0, 357090.0, 0.002291666666666667, 0.004131944444444444]
# ['Mot exact', 'qui', '', '', '', 'qui a dit ça ?', 'ESLO2_LIVRENF_1313', 'ESLO2_LIVRENF_1313_C', 'LEC_BV405', 256853.0, 357090.0, 0.002962962962962963, 0.004131944444444444]
# ['Mot exact', 'qui', '', '', '', "c'est toi qui as fait un rototo ?", 'ESLO2_LIVRENF_1314', 'ESLO2_LIVRENF_1314_C', 'LEC_SP932', 184971.0, 187299.0, 0.00212962962962963, 0.002164351851851852]
# ['Mot exact', 'qui', '', '', '', 'qui a dit ça ?', 'ESLO2_LIVRENF_1314', 'ESLO2_LIVRENF_1314_C', 'LEC_SP932', 292741.0, 389775.0, 0.00337962962962963, 0.004502314814814815]
# ['Mot exact', 'qui', '', '', '', 'qui les attrapera en premier ?', 'ESLO2_LIVRENF_1316', 'ESLO2_LIVRENF_1316_C', 'LEC_ZF132', 123539.0, 142773.0, 0.001423611111111111, 0.001643518518518518]
# ['Mot exact', 'qui', '', '', '', 'qui les mangera en premier ?', 'ESLO2_LIVRENF_1316', 'ESLO2_LIVRENF_1316_C', 'LEC_ZF132', 171888.0, 202534.0, 0.001979166666666667, 0.002337962962962963]
# ['Mot exact', 'qui', '', '', '', 'qui le mangera en premier ?', 'ESLO2_LIVRENF_1316', 'ESLO2_LIVRENF_1316_C', 'LEC_ZF132', 224939.0, 234950.0, 0.002592592592592593, 0.002708333333333333]
# ['Mot exact', 'qui', '', '', '', "c'est qui Suzana ?", 'ESLO2_LIVRENF_1317', 'ESLO2_LIVRENF_1317_C', 'ENF_GW809', 74948.0, 77730.0, 0.0008564814814814815, 0.0008912037037037036]
# ['Mot exact', 'qui', '', '', '', "oh c'est des fleurs et puis ça c'est qui ça ?", 'ESLO2_LIVRENF_1319', 'ESLO2_LIVRENF_1319_C', 'LEC_JJ762', 216652.0, 218874.0, 0.0025, 0.002523148148148148]
# ['Mot exact', 'qui', '', '', '', 'qui est là ? cria la grand-mére', 'ESLO2_LIVRENF_1319', 'ESLO2_LIVRENF_1319_C', 'LEC_JJ762', 251581.0, 283886.0, 0.002905092592592593, 0.003275462962962963]
# ['Mot exact', 'qui', '', '', '', 'oh des fleurs que le Petit Chaperon Rouge elle apporte à qui ?', 'ESLO2_LIVRENF_1319', 'ESLO2_LIVRENF_1319_C', 'LEC_JJ762', 284860.0, 287572.0, 0.003287037037037037, 0.003321759259259259]
# ['Mot exact', 'qui', '', '', '', "il va te lire ce qui a d'écrit OK ?", 'ESLO2_LIVRENF_1321', 'ESLO2_LIVRENF_1321_C', 'LEC_HT474', 26849.0, 94690.0, 0.0003009259259259259, 0.001087962962962963]
# ['Mot exact', 'qui', '', '', '', 'à ce que porte grand-maman Donald savez-vous ce que qui clochait avec le déguisement ?', 'ESLO2_LIVRENF_1321', 'ESLO2_LIVRENF_1321_C', 'LEC_HT474', 358576.0, 375637.0, 0.004143518518518519, 0.004340277777777778]
# ['Mot exact', 'qui', '', '', '', 'à qui Petit Ours Brun dit bonjour chaque matin ?', 'ESLO2_LIVRENF_1322', 'ESLO2_LIVRENF_1322_C', 'LEC_ST446', 10155.0, 104772.0, 0.0001157407407407407, 0.001203703703703704]
# ['Mot exact', 'qui', '', '', '', 'qui vient prés du grillage quand on tend une carotte ?', 'ESLO2_LIVRENF_1322', 'ESLO2_LIVRENF_1322_C', 'LEC_ST446', 54179.0, 104772.0, 0.000625, 0.001203703703703704]
# ['Mot exact', 'qui', '', '', '', 'qui fait cot cot codec quand on jette des grains ?', 'ESLO2_LIVRENF_1322', 'ESLO2_LIVRENF_1322_C', 'LEC_ST446', 83298.0, 104772.0, 0.0009606481481481481, 0.001203703703703704]
# ['Mot exact', 'qui', '', '', '', 'parmi les animaux de la terre qui est celui que Petit Ours Brun préfére ?', 'ESLO2_LIVRENF_1322', 'ESLO2_LIVRENF_1322_C', 'LEC_ST446', 94194.0, 104772.0, 0.001087962962962963, 0.001203703703703704]
# ['Mot exact', 'qui', '', '', '', "qui c'est Mauricette ?", 'ESLO2_LIVRENF_1323', 'ESLO2_LIVRENF_1323_C', 'LEC_FQ654', 111190.0, 118005.0, 0.001284722222222222, 0.001365740740740741]
# ['Mot exact', 'qui', '', '', '', "qui es-tu ? demande l'un", 'ESLO2_LIVRENF_1325', 'ESLO2_LIVRENF_1325_C', 'LEC_XW117', 92570.0, 192216.0, 0.001064814814814815, 0.002222222222222222]
# ['Mot exact', 'qui', '', '', '', "qui se perdent aussitôt dans l'immense océan ?", 'ESLO2_LIVRENF_1325', 'ESLO2_LIVRENF_1325_C', 'LEC_XW117', 418633.0, 431263.0, 0.004837962962962963, 0.004988425925925927]
# ['Mot exact', 'qui', '', '', '', 'elle part loin et elle part avec qui là ?', 'ESLO2_LIVRENF_1327', 'ESLO2_LIVRENF_1327_C', 'LEC_RF060', 299173.0, 301285.0, 0.003460648148148148, 0.003483796296296296]
# ['Mot exact', 'qui', '', '', '', "[main'nant:pronounce:instantaneous] qui c'est qui est pas content ?", 'ESLO2_LIVRENF_1327', 'ESLO2_LIVRENF_1327_C', 'LEC_RF060', 435070.0, 436914.0, 0.005034722222222223, 0.005046296296296296]
# ['Mot exact', 'qui', '', '', '', "qui qu'est pas content ?", 'ESLO2_LIVRENF_1327', 'ESLO2_LIVRENF_1327_C', 'KX208', 550508.0, 551795.0, 0.00636574074074074, 0.006377314814814815]
# ['Mot exact', 'qui', '', '', '', 'et tu sais ce qui arrive aux petits garçons qui ne veulent pas manger leur soupe ?', 'ESLO2_LIVRENF_1328', 'ESLO2_LIVRENF_1328_C', 'LEC_BT824', 99806.0, 103644.0, 0.001145833333333333, 0.00119212962962963]
# ['Mot exact', 'qui', '', '', '', "qui étaient o˘ celles-ci ? c'est celles qui étaient euh", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 56014.0, 59242.0, 0.0006481481481481481, 0.0006828703703703703]
# ['Mot exact', 'qui', '', '', '', 'non non elles étaient là celles qui étaient ici ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 59242.0, 61002.0, 0.0006828703703703703, 0.0007060185185185185]
# ['Mot exact', 'qui', '', '', '', 'qui vous plaisait dans les baraques en bois ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 273942.0, 276272.0, 0.003159722222222222, 0.003194444444444444]
# ['Mot exact', 'qui', '', '', '', "et il avait bien voulu se marier avec quelqu'un qui voyageait pas ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 409239.0, 412742.0, 0.004733796296296296, 0.004768518518518518]
# ['Mot exact', 'qui', '', '', '', 'et y en a pas qui ont voyagé ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 456927.0, 458604.0, 0.005277777777777777, 0.005300925925925925]
# ['Mot exact', 'qui', '', '', '', "y en a aucun qui a eu envie c'est ça ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 466035.0, 467293.0, 0.005393518518518519, 0.005405092592592592]
# ['Mot exact', 'qui', '', '', '', "c'est ça qui était bien ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 559637.0, 560505.0, 0.006469907407407407, 0.006481481481481481]
# ['Mot exact', 'qui', '', '', '', 'qui étaient ensemble ? qui main dans la main ? ou non tout le monde ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 796661.0, 799020.0, 0.009212962962962963, 0.009247685185185185]
# ['Mot exact', 'qui', '', '', '', "ouais c'est c'est François qui est décédé en deux mille trois non ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'BW955', 1176755.0, 1181886.0, 0.01361111111111111, 0.01366898148148148]
# ['Mot exact', 'qui', '', '', '', 'qui gueulait le plus ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 1620702.0, 1622678.0, 0.01875, 0.01877314814814815]
# ['Mot exact', 'qui', '', '', '', 'mais qui les appelait les flics en fait ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 2094953.0, 2096564.0, 0.02423611111111111, 0.02425925925925926]
# ['Mot exact', 'qui', '', '', '', "et alors qui c'est qui s'en occupait ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 2263571.0, 2265152.0, 0.02619212962962963, 0.02621527777777778]
# ['Mot exact', 'qui', '', '', '', "ouais et pis y avait pas je sais pas pas d'autres quartiers d'Orléans qui qui é- non non ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 2365816.0, 2369050.0, 0.02737268518518518, 0.02741898148148149]
# ['Mot exact', 'qui', '', '', '', 'visiter ou ouais venaient euh ouais avec qui ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 2731512.0, 2734889.0, 0.03160879629629629, 0.03164351851851852]
# ['Mot exact', 'qui', '', '', '', 'particuliére qui était vraiment au Groues ? l-', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 2781863.0, 2788576.0, 0.0321875, 0.03226851851851852]
# ['Mot exact', 'qui', '', '', '', "y a d'autres et y a d'autres qui ont changé là c- comme ça ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 2822682.0, 2835264.0, 0.03266203703703704, 0.0328125]
# ['Mot exact', 'qui', '', '', '', 'qui avaient la télé ? ouais ? bon', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 2928193.0, 2929421.0, 0.03388888888888889, 0.03390046296296297]
# ['Mot exact', 'qui', '', '', '', 'y a des femmes qui sont nourriciéres tu vois ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'BW955', 3251346.0, 3253772.0, 0.03762731481481481, 0.03765046296296296]
# ['Mot exact', 'qui', '', '', '', "parce qu'il y avait la Chil- y avait la Chilesse qui passait en dessous c'est ça ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'MF363', 3264032.0, 3266880.0, 0.03777777777777778, 0.03780092592592593]
# ['Mot exact', 'qui', '', '', '', 'qui sont nés aux Groues et qui ont vécu aux Groues tout le temps ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'MF363', 3871519.0, 3876004.0, 0.04480324074074074, 0.04486111111111111]
# ['Mot exact', 'qui', '', '', '', 'ah ouais y a des gens qui sont venus dans les baraques aprés ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 3941386.0, 3951035.0, 0.04561342592592593, 0.04572916666666666]
# ['Mot exact', 'qui', '', '', '', "c'est quoi c'est leur famille qui venait là ? euh", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 3945829.0, 3951035.0, 0.04565972222222223, 0.04572916666666666]
# ['Mot exact', 'qui', '', '', '', "dans les immeubles y a des gens qui sont venus de l'extérieur ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 3968714.0, 3970451.0, 0.04592592592592593, 0.04594907407407408]
# ['Mot exact', 'qui', '', '', '', 'qui ont comment dire là ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'MF363', 4082058.0, 4084156.0, 0.04724537037037038, 0.04726851851851852]
# ['Mot exact', 'qui', '', '', '', 'et qui sont partis aprés avec eux ?', 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 4119523.0, 4121224.0, 0.0476736111111111, 0.04769675925925926]
# ['Mot exact', 'qui', '', '', '', "et ça c'est une recette qui vient de famille ?", 'ESLO2_ENT_1329', 'ESLO2_ENT_1329_C', 'ch_OB1', 4261454.0, 4263514.0, 0.04931712962962963, 0.04934027777777777]
# ['Mot exact', 'qui', '', '', '', '[bb:noise:instantaneous] euh qu- qui en reveut ?', 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343MER', 616664.0, 618987.0, 0.007129629629629631, 0.007152777777777779]
# ['Mot exact', 'qui', '', '', '', "qui c'est qui bouffe les os là ?", 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343', 923712.2, 936026.0, 0.01068287037037037, 0.01083333333333333]
# ['Mot exact', 'qui', '', '', '', 'qui veut du pain ?', 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343BPER', 1329142.0, 1330927.0, 0.01538194444444444, 0.01539351851851852]
# ['Mot exact', 'qui', '', '', '', 'oui mais qu- qui en veut ?', 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343BPER', 1331637.0, 1334795.0, 0.01540509259259259, 0.01543981481481482]
# ['Mot exact', 'qui', '', '', '', 'et tu es avec qui ?', 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343', 1911794.0, 1913788.0, 0.02211805555555556, 0.0221412037037037]
# ['Mot exact', 'qui', '', '', '', "qui c'est qui voudra du dessert ?", 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343MER', 2120009.0, 2121652.0, 0.02453703703703704, 0.02454861111111111]
# ['Mot exact', 'qui', '', '', '', 'qui veut la moitié ?', 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343BPER', 2510521.0, 2511639.0, 0.02905092592592593, 0.0290625]
# ['Mot exact', 'qui', '', '', '', "puis alors les collégues qui disaient ah bon tu connais ? et tout elle dit oh oui bah chez nous c'est quand même euh", 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343MER', 3938594.0, 3942897.0, 0.0455787037037037, 0.045625]
# ['Mot exact', 'qui', '', '', '', "c'est qui ?", 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343MER', 4302459.0, 4303882.0, 0.04979166666666667, 0.04980324074074074]
# ['Mot exact', 'qui', '', '', '', "c'est qui ?", 'ESLO2_REPAS_1330', 'ESLO2_REPAS_1330_C', 'BD343MER', 4308432.0, 4309843.0, 0.04986111111111111, 0.04987268518518518]
# We created a list that embeds 2656 lists.

# %%
# iterates through list of lists and populates empty cells

# wh = 'qui'
string = 'est-ce'
string_count = 0
string2 = 'c\'est\squi'
string2b = 'qui\sc\'est'
string2_count = 0

ex_situ_count = 0
in_situ_count = 0
fragment_count = 0
sv_count = 0

for list in all_rows:
    
    text = list[5] # index 5 is where text of interest is stored, returns a cell

    if search(string, text):
        list[2] = 'ex situ'
        list[3] = 'est-ce que'
        list[4] = 'formed' # then check manually and change to 'fragment' if needed
        string_count += 1
    elif search(string2, text) or search(string2b, text):
        list[3] = 'cleft'

        if search(string2, text):
            list[2] = 'in situ'
        elif search(string2b, text):
            list[2] = 'ex situ'
        string2_count += 1

    if re.search('^qui\s', text, flags=0) or re.search('^et\squi\s', text, flags=0) or re.search('^alors\squi\s', text, flags=0) or re.search('^et\salors\squi\s', text, flags=0):
        list[2] = 'ex situ'
        list[4] = 'formed' # then check manually and change to 'fragment' if needed
        ex_situ_count += 1

        if search(string2, text) or search(string2b, text):
            list[3] = 'cleft'
        elif text.endswith('qui ?') or text.endswith('qui ça ?') or text.endswith('qui alors ?'):
            list[2] = 'wh'
            list[3] = 'none'
            list[4] = 'fragment'
            fragment_count += 1
        elif re.search('^qui\sje', text, flags=0) or re.search('^qui\stu', text, flags=0) or re.search('^qui\selle', text, flags=0) or re.search('^qui\sil', text, flags=0) or re.search('^qui\snous', text, flags=0) or re.search('^qui\svous', text, flags=0) or re.search('^qui\selles', text, flags=0) or re.search('^qui\sils', text, flags=0) or re.search('^qui\sça', text, flags=0):
            list[3] = 'SV'
            list[4] = 'formed'
            sv_count += 1
        elif re.search('^qui\sje', text, flags=0):
            list[3] = 'que'

    elif text.endswith('qui ?'):
        list[2] = 'in situ'
        list[3] = 'SV'
        list[4] = 'final'
        in_situ_count += 1
        
    elif text.endswith('qui alors ?') or text.endswith('qui ça ?') or text.endswith('qui madame ?') or text.endswith('qui monsieur ?') or text.endswith('qui vous ?'):
        list[2] = 'in situ'
        list[3] = 'SV'
        list[4] = 'non final'
        in_situ_count += 1

print(f'{string_count} occurrences of \'est-ce que\' found.')
print(f'{string2_count} occurrences of \'c\'est\' found.')
print(f'{ex_situ_count} occurrences of \'qui\' ex situ found.')
print(f'{in_situ_count} occurrences of \'qui\' in situ found.')
print(f'{fragment_count} occurrences of fragments found.')
print(f'{sv_count} occurrences of SV ordering found.')
# Out:
# 697 occurrences of 'est-ce que' found.
# 114 occurrences of 'c'est' found.
# 703 occurrences of 'qui' ex situ found.
# 112 occurrences of 'qui' in situ found.
# 25 occurrences of fragments found.
# 43 occurrences of SV ordering found.

# %% [markdown]
# We will now create a new .xlsx file with all the classified data.

# %%
# creates spreadsheet using each nested list as a row

df = pd.DataFrame(data=all_rows)

# converts into excel
df.to_excel("all_rows_classified.xlsx", index=False)

print("Dictionary converted into excel...")
# Out:
# Dictionary converted into excel...

# %%
# opens the new excel sheet and reads it
# I created a .xls copy of the .xlsx file manually otherwise it won't open

file2 = 'all_rows_classified.xls'
data2 = pd.ExcelFile(file2)

# returns the all the sheet names within the excel file
print(data2.sheet_names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [32], line 5
#       1 # opens the new excel sheet and reads it
#       2 # I created a .xls copy of the .xlsx file manually otherwise it won't open
#       4 file2 = 'all_rows_classified.xls'
# ----> 5 data2 = pd.ExcelFile(file2)
#       7 # returns the all the sheet names within the excel file
#       8 print(data2.sheet_names)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1373'>1374</a>     ext = "xls"
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1374'>1375</a> else:
# -> <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1375'>1376</a>     ext = inspect_excel_format(
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1376'>1377</a>         content_or_path=path_or_buffer, storage_options=storage_options
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1377'>1378</a>     )
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1378'>1379</a>     if ext is None:
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1379'>1380</a>         raise ValueError(
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1380'>1381</a>             "Excel file format cannot be determined, you must specify "
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1381'>1382</a>             "an engine manually."
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1382'>1383</a>         )
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1246'>1247</a> if isinstance(content_or_path, bytes):
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1247'>1248</a>     content_or_path = BytesIO(content_or_path)
# -> <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1249'>1250</a> with get_handle(
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1250'>1251</a>     content_or_path, "rb", storage_options=storage_options, is_text=False
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1251'>1252</a> ) as handle:
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1252'>1253</a>     stream = handle.handle
#    <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/excel/_base.py?line=1253'>1254</a>     stream.seek(0)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/io/common.py:795, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=785'>786</a>         handle = open(
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=786'>787</a>             handle,
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=787'>788</a>             ioargs.mode,
#    (...)
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=790'>791</a>             newline="",
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=791'>792</a>         )
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=792'>793</a>     else:
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=793'>794</a>         # Binary mode
# --> <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=794'>795</a>         handle = open(handle, ioargs.mode)
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=795'>796</a>     handles.append(handle)
#     <a href='file:///Users/caterinabonan/miniforge3/lib/python3.9/site-packages/pandas/io/common.py?line=797'>798</a> # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all_rows_classified.xls'

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame2 = data2.parse('Sheet1')
data_frame2.info

# only shows the first 60 rows
data_frame2.head(60)
