# %% [markdown]
# This code is to classify the selected examples automatically for those criteria that allow automatic classification.

# %%
import pandas as pd
import xlrd
import re
from re import search

# %%
# opens the excel sheet and reads it
# excel sheet needs to be in the same working directory as this file

file = 'selected_rows_sorted.xls'
data = pd.ExcelFile(file)

 # returns the all the sheet names within the excel file
print(data.sheet_names)
# Out:
# ['Sheet1']

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame = data.parse('Sheet1')
data_frame.info

# only shows the first 10 rows
data_frame.head(10)
# Out:
#            0    1  wh  int  other  \
# 0  Mot exact  qui NaN  NaN    NaN
# 1  Mot exact  qui NaN  NaN    NaN
# 2  Mot exact  qui NaN  NaN    NaN
# 3  Mot exact  qui NaN  NaN    NaN
# 4  Mot exact  qui NaN  NaN    NaN
# 5  Mot exact  qui NaN  NaN    NaN
# 6  Mot exact  qui NaN  NaN    NaN
# 7  Mot exact  qui NaN  NaN    NaN
# 8  Mot exact  qui NaN  NaN    NaN
# 9  Mot exact  qui NaN  NaN    NaN
#
#                                                    9              2  \
# 0               trés bien qui habitent la rue hein ?  ESLO1_ENT_017
# 1                           qui habitent le ah bon ?  ESLO1_ENT_017
# 2  qu'est-ce qui vous plaît et qu'est-ce qui vous...  ESLO1_ENT_017
# 3  quelles sont les choses qui vous plaisent le p...  ESLO1_ENT_017
# 4  qu'est-ce que vous pensez des des femmes marié...  ESLO1_ENT_017
# 5      qu'est-ce qui leur plaît dans leurs loisirs ?  ESLO1_ENT_017
# 6  alors à Orléans qui est-ce qui va à la maison ...  ESLO1_ENT_017
# 7  à votre avis qu'est-ce qui fait que les enfant...  ESLO1_ENT_017
# 8  quelles sont les p- les personnes qui comptent...  ESLO1_ENT_017
# 9  vous pouvez expliquer un peu ce qui s'est passé ?  ESLO1_ENT_017
#
#                  3      4          5          6         7         8
# 0  ESLO1_ENT_017_C  QB100    97160.0    98641.0  0.001123  0.001134
# 1  ESLO1_ENT_017_C     CS   370289.0   371481.0  0.004282  0.004294
# 2  ESLO1_ENT_017_C     CS   730114.0   738206.0  0.008449  0.008542
# 3  ESLO1_ENT_017_C     CS   734543.0   738206.0  0.008495  0.008542
# 4  ESLO1_ENT_017_C     CS   768372.0   772569.0  0.008889  0.008935
# 5  ESLO1_ENT_017_C  QB100  1031781.0  1038519.0  0.011933  0.012014
# 6  ESLO1_ENT_017_C     CS  1062853.0  1065278.0  0.012292  0.012326
# 7  ESLO1_ENT_017_C     CS  1366299.0  1373565.0  0.015810  0.015891
# 8  ESLO1_ENT_017_C     CS  1859247.0  1864205.0  0.021516  0.021574
# 9  ESLO1_ENT_017_C     CS  2026649.0  2038217.0  0.023449  0.023588

# %%
# reads in the spreadsheet data

workbook = xlrd.open_workbook('selected_rows_sorted.xls')
sheet = workbook.sheet_by_name('Sheet1')

# gets the first sheet
sheet_1 = workbook.sheet_by_index(0)

row_count = sheet.nrows
col_count = sheet.ncols
print(f'Total rows: {row_count}\nTotal columns: {col_count}')
# Out:
# Total rows: 3162
# Total columns: 13

# %% [markdown]
# We're now going to create a new list of lists out of the file, and populate the empty columns with as much data as possible.
#
# The data that should be easy to classify automatically are: est-ce que / wh- at the beginning or end of sentence / presence of c'est.

# %%
# initialises list of lists
all_rows = []
unwanted_segment = 'qu\'est-ce\squi'
row_count = 0

for rx in range(sheet.nrows): # rx is an int, row is a list 
    row = sheet.row(rx)
    row_count += 1
    if row_count == 1:
        continue
    else:
        # initialises list that will contain our data
        data_list = []

        # populates list that stores all rows
        data_list.append(row[0].value)
        data_list.append(row[1].value)
        data_list.append(row[2].value) # wh
        data_list.append(row[3].value) # int
        data_list.append(row[4].value) # other
        data_list.append(row[6].value)
        data_list.append(row[7].value)
        data_list.append(row[8].value)
        data_list.append(row[9].value)
        data_list.append(row[10].value)
        data_list.append(row[11].value)
        data_list.append(row[12].value)

        # excludes all utterances containing 'qu'est-ce qui'
        utterance = row[5].value
        if search(unwanted_segment, utterance):
            # print(unwanted_segment)
            continue
        else:
            data_list.append(utterance) # segment

        all_rows.append(data_list)
        # print(all_rows)
        
# prints extracted rows
print(f'We created a list that embeds {len(all_rows)} lists.')
# Out:
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# qu'est-ce\squi
# We created a list that embeds 2655 lists.

# %%
# iterates through list of lists and populates empty cells

row = 0

wh = 'qui'
string = 'est-ce'
string_count = 0
string2 = 'c\'est\squi'
string2b = 'qui\sc\'est'
string2_count = 0

ex_situ_count = 0
in_situ_count = 0
fragment_count = 0
sv_count = 0

for list in all_rows:
    row += 1
    if row == 1:
        continue
    else:
        text = list[5] # index 5 is where text of interest is stored, returns a cell

        if search(string, text):
            list[2] = 'ex situ'
            list[3] = 'est-ce que'
            list[4] = 'formed' # then check manually and change to 'fragment' if needed
            string_count += 1
        elif search(string2, text) or search(string2b, text):
            list[3] = 'cleft'

            if search(string2, text):
                list[2] = 'in situ'
            elif search(string2b, text):
                list[2] = 'ex situ'
            string2_count += 1

        if re.search('^qui\s', text, flags=0) or re.search('^et\squi\s', text, flags=0) or re.search('^alors\squi\s', text, flags=0) or re.search('^et\salors\squi\s', text, flags=0):
            list[2] = 'ex situ'
            list[4] = 'formed' # then check manually and change to 'fragment' if needed
            ex_situ_count += 1

            if search(string2, text) or search(string2b, text):
                list[3] = 'cleft'
            elif text.endswith('qui ?') or text.endswith('qui ça ?') or text.endswith('qui alors ?'):
                list[2] = 'wh'
                list[3] = 'none'
                list[4] = 'fragment'
                fragment_count += 1
            elif re.search('^qui\sje', text, flags=0) or re.search('^qui\stu', text, flags=0) or re.search('^qui\selle', text, flags=0) or re.search('^qui\sil', text, flags=0) or re.search('^qui\snous', text, flags=0) or re.search('^qui\svous', text, flags=0) or re.search('^qui\selles', text, flags=0) or re.search('^qui\sils', text, flags=0) or re.search('^qui\sça', text, flags=0):
                list[3] = 'SV'
                list[4] = 'formed'
                sv_count += 1
            elif re.search('^qui\sje', text, flags=0):
                list[3] = 'que'

        elif text.endswith('qui ?'):
            list[2] = 'in situ'
            list[3] = 'SV'
            list[4] = 'final'
            in_situ_count += 1
        
        elif text.endswith('qui alors ?') or text.endswith('qui ça ?') or text.endswith('qui madame ?') or text.endswith('qui monsieur ?') or text.endswith('qui vous ?'):
            list[2] = 'in situ'
            list[3] = 'SV'
            list[4] = 'non final'
            in_situ_count += 1

print(f'{string_count} occurrences of \'est-ce que\' found.')
print(f'{string2_count} occurrences of \'c\'est\' found.')
print(f'{ex_situ_count} occurrences of \'qui\' ex situ found.')
print(f'{in_situ_count} occurrences of \'qui\' in situ found.')
print(f'{fragment_count} occurrences of fragments found.')
print(f'{sv_count} occurrences of SV ordering found.')
# Out:
# 0 occurrences of 'est-ce que' found.
# 0 occurrences of 'c'est' found.
# 0 occurrences of 'qui' ex situ found.
# 0 occurrences of 'qui' in situ found.
# 0 occurrences of fragments found.
# 0 occurrences of SV ordering found.

# %% [markdown]
# We will now create a new .xlsx file with all the classified data.

# %%
# creates spreadsheet using each nested list as a row

df = pd.DataFrame(data=all_rows)

# converts into excel
df.to_excel("all_rows_classified.xlsx", index=False)

print("Dictionary converted into excel...")
# Out:
# Dictionary converted into excel...

# %%
# opens the new excel sheet and reads it
# I created a .xls copy of the .xlsx file manually otherwise it won't open

file2 = 'all_rows_classified.xls'
data2 = pd.ExcelFile(file2)

# returns the all the sheet names within the excel file
print(data2.sheet_names)
# Out:
# ['Sheet1']

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame2 = data2.parse('Sheet1')
data_frame2.info

# only shows the first 60 rows
data_frame2.head(60)
# Out:
#            0    1        2           3       4   \
# 0           0    1       wh         int   other
# 1   Mot exact  qui      NaN         NaN     NaN
# 2   Mot exact  qui  ex situ         NaN  formed
# 3   Mot exact  qui  ex situ  est-ce que  formed
# 4   Mot exact  qui      NaN         NaN     NaN
# 5   Mot exact  qui  ex situ  est-ce que  formed
# 6   Mot exact  qui  ex situ  est-ce que  formed
# 7   Mot exact  qui  ex situ  est-ce que  formed
# 8   Mot exact  qui  ex situ  est-ce que  formed
# 9   Mot exact  qui      NaN         NaN     NaN
# 10  Mot exact  qui      NaN         NaN     NaN
# 11  Mot exact  qui      NaN         NaN     NaN
# 12  Mot exact  qui  ex situ  est-ce que  formed
# 13  Mot exact  qui  ex situ  est-ce que  formed
# 14  Mot exact  qui  ex situ  est-ce que  formed
# 15  Mot exact  qui      NaN         NaN     NaN
# 16  Mot exact  qui      NaN         NaN     NaN
# 17  Mot exact  qui      NaN         NaN     NaN
# 18  Mot exact  qui  ex situ  est-ce que  formed
# 19  Mot exact  qui  ex situ  est-ce que  formed
# 20  Mot exact  qui  ex situ  est-ce que  formed
# 21  Mot exact  qui  ex situ         NaN  formed
# 22  Mot exact  qui      NaN         NaN     NaN
# 23  Mot exact  qui      NaN         NaN     NaN
# 24  Mot exact  qui  ex situ  est-ce que  formed
# 25  Mot exact  qui  ex situ  est-ce que  formed
# 26  Mot exact  qui      NaN         NaN     NaN
# 27  Mot exact  qui  ex situ  est-ce que  formed
# 28  Mot exact  qui      NaN         NaN     NaN
# 29  Mot exact  qui  ex situ  est-ce que  formed
# 30  Mot exact  qui      NaN         NaN     NaN
# 31  Mot exact  qui      NaN         NaN     NaN
# 32  Mot exact  qui  ex situ  est-ce que  formed
# 33  Mot exact  qui      NaN         NaN     NaN
# 34  Mot exact  qui  ex situ  est-ce que  formed
# 35  Mot exact  qui  ex situ  est-ce que  formed
# 36  Mot exact  qui  ex situ  est-ce que  formed
# 37  Mot exact  qui      NaN         NaN     NaN
# 38  Mot exact  qui      NaN         NaN     NaN
# 39  Mot exact  qui  ex situ  est-ce que  formed
# 40  Mot exact  qui  ex situ  est-ce que  formed
# 41  Mot exact  qui  ex situ  est-ce que  formed
# 42  Mot exact  qui  ex situ  est-ce que  formed
# 43  Mot exact  qui  ex situ  est-ce que  formed
# 44  Mot exact  qui      NaN         NaN     NaN
# 45  Mot exact  qui      NaN         NaN     NaN
# 46  Mot exact  qui  ex situ  est-ce que  formed
# 47  Mot exact  qui  ex situ         NaN  formed
# 48  Mot exact  qui  ex situ  est-ce que  formed
# 49  Mot exact  qui  ex situ  est-ce que  formed
# 50  Mot exact  qui  ex situ  est-ce que  formed
# 51  Mot exact  qui  ex situ  est-ce que  formed
# 52  Mot exact  qui      NaN         NaN     NaN
# 53  Mot exact  qui  ex situ  est-ce que  formed
# 54  Mot exact  qui  ex situ  est-ce que  formed
# 55  Mot exact  qui  ex situ  est-ce que  formed
# 56  Mot exact  qui      NaN         NaN     NaN
# 57  Mot exact  qui  ex situ  est-ce que  formed
# 58  Mot exact  qui  ex situ  est-ce que  formed
# 59  Mot exact  qui  ex situ  est-ce que  formed
#
#                                                    5              6   \
# 0                                                   9              2
# 1                trés bien qui habitent la rue hein ?  ESLO1_ENT_017
# 2                            qui habitent le ah bon ?  ESLO1_ENT_017
# 3   qu'est-ce qui vous plaît et qu'est-ce qui vous...  ESLO1_ENT_017
# 4   quelles sont les choses qui vous plaisent le p...  ESLO1_ENT_017
# 5   qu'est-ce que vous pensez des des femmes marié...  ESLO1_ENT_017
# 6       qu'est-ce qui leur plaît dans leurs loisirs ?  ESLO1_ENT_017
# 7   alors à Orléans qui est-ce qui va à la maison ...  ESLO1_ENT_017
# 8   à votre avis qu'est-ce qui fait que les enfant...  ESLO1_ENT_017
# 9   quelles sont les p- les personnes qui comptent...  ESLO1_ENT_017
# 10  vous pouvez expliquer un peu ce qui s'est passé ?  ESLO1_ENT_017
# 11  parmi vos vos connaissances quelle serait la p...  ESLO1_ENT_017
# 12  est-ce qu'à votre avis en France y a un organi...  ESLO1_ENT_017
# 13  et vous personnellement qu'est-ce que vous pen...  ESLO1_ENT_018
# 14  est-ce qu'il y a des professions qui vous semb...  ESLO1_ENT_018
# 15  il y a encore des professions qui ne demandent...  ESLO1_ENT_018
# 16  en général c'est vous ou votre femme qui s'occ...  ESLO1_ENT_018
# 17  enfin c'est elle qui décide aussi par exemple ...  ESLO1_ENT_018
# 18  est-ce qu'il y a des matiéres qui vous paraiss...  ESLO1_ENT_018
# 19  et est-ce qu'il y a des matiéres qui vous semb...  ESLO1_ENT_018
# 20  et qu'est-ce que vous pensez des parents qui p...  ESLO1_ENT_018
# 21                       qui poussent leurs enfants ?  ESLO1_ENT_018
# 22  et comment vous expliquez qu'il y ait des enfa...  ESLO1_ENT_018
# 23  entre celui qui voit l'ensemble du probléme en...  ESLO1_ENT_018
# 24  et qu'est-ce qui comptait le plus pour vous da...  ESLO1_ENT_019
# 25         c'est-à-dire qu'est-ce qui vous plaisait ?  ESLO1_ENT_019
# 26  vous en avez d'autres qui sont moins bien élev...  ESLO1_ENT_019
# 27  et qu'est-ce qui fait que les enfants réussiss...  ESLO1_ENT_019
# 28  mais pour l'éléve moyen alors qui n'a pas beau...  ESLO1_ENT_019
# 29  j'allais vous demander est-ce que vous pourrie...  ESLO1_ENT_019
# 30  quelle est la personne qui parle le mieux le f...  ESLO1_ENT_019
# 31  y a-t-il en France euh un organisme officiel q...  ESLO1_ENT_019
# 32  et qu'est-ce qui qu'est-ce qui compte le plus ...  ESLO1_ENT_020
# 33  et quelles sont les choses qui vous plaisent e...  ESLO1_ENT_020
# 34  et si vous ne faisiez pas ce ce métier-là qu'e...  ESLO1_ENT_020
# 35  qu'est-ce qui est important enfin le quel devr...  ESLO1_ENT_020
# 36  et d'aprés vous qu'est-ce comment ce qu'est-ce...  ESLO1_ENT_020
# 37  je veux dire quelles sont les personnes à Orlé...  ESLO1_ENT_020
# 38  quel est le le la personne ou le type de profe...  ESLO1_ENT_020
# 39  est-ce que vous vous pensez qu'il y a en Franc...  ESLO1_ENT_020
# 40  et si vous deviez euh dire quelque chose à que...  ESLO1_ENT_020
# 41  est-ce que dans la façon de parler de de votre...  ESLO1_ENT_020
# 42  qui est-ce qui reprend l'autre le plus souvent...  ESLO1_ENT_020
# 43  qui est-ce qui reprenait votre pére ou votre m...  ESLO1_ENT_020
# 44           qu'est ce qui vous a amené à vivre ici ?  ESLO1_ENT_021
# 45  il n'y a pas de chose qui vous déplait alors d...  ESLO1_ENT_021
# 46  mais qui est-ce qui s'en sert le plus souvent ...  ESLO1_ENT_021
# 47  qui d'entre vous avait la meilleure orthograph...  ESLO1_ENT_021
# 48  dans le temps n'est-ce pas qui vous agaçaient ...  ESLO1_ENT_021
# 49  qu'est-ce qui comptait le plus pour vous dans ...  ESLO1_ENT_022
# 50  et ce match ce mois de juin qui vient qu'est-c...  ESLO1_ENT_022
# 51  et qu'est-ce qui fait que les enfants réussiss...  ESLO1_ENT_022
# 52             il y a des gens qui parlent pas bien ?  ESLO1_ENT_022
# 53          qui est-ce qui s'en sert le plus souvent?  ESLO1_ENT_022
# 54  qu'est-ce qu'est-ce qui vous plait surtout à O...  ESLO1_ENT_023
# 55  et qu'est-ce qui vous plait dans votre travail...  ESLO1_ENT_023
# 56                      c'est vous qui l'avez prise ?  ESLO1_ENT_023
# 57  qu'est-ce que vous pensez du travail des des f...  ESLO1_ENT_023
# 58  est-ce que parmi vos petits-enfants y en a qui...  ESLO1_ENT_023
# 59  et à votre avis qu'est-ce qui fait que les enf...  ESLO1_ENT_023
#
#                  7      8          9          10        11        12
# 0                 3      4        5.0        6.0  7.000000  8.000000
# 1   ESLO1_ENT_017_C  QB100    97160.0    98641.0  0.001123  0.001134
# 2   ESLO1_ENT_017_C     CS   370289.0   371481.0  0.004282  0.004294
# 3   ESLO1_ENT_017_C     CS   730114.0   738206.0  0.008449  0.008542
# 4   ESLO1_ENT_017_C     CS   734543.0   738206.0  0.008495  0.008542
# 5   ESLO1_ENT_017_C     CS   768372.0   772569.0  0.008889  0.008935
# 6   ESLO1_ENT_017_C  QB100  1031781.0  1038519.0  0.011933  0.012014
# 7   ESLO1_ENT_017_C     CS  1062853.0  1065278.0  0.012292  0.012326
# 8   ESLO1_ENT_017_C     CS  1366299.0  1373565.0  0.015810  0.015891
# 9   ESLO1_ENT_017_C     CS  1859247.0  1864205.0  0.021516  0.021574
# 10  ESLO1_ENT_017_C     CS  2026649.0  2038217.0  0.023449  0.023588
# 11  ESLO1_ENT_017_C     CS  3569081.0  3578155.0  0.041308  0.041412
# 12  ESLO1_ENT_017_C     CS  3847779.0  3857143.0  0.044525  0.044641
# 13  ESLO1_ENT_018_C     BV  1139919.0  1144385.0  0.013183  0.013241
# 14  ESLO1_ENT_018_C     BV  1279241.0  1283616.0  0.014803  0.014850
# 15  ESLO1_ENT_018_C     BV  1317345.0  1320876.0  0.015243  0.015278
# 16  ESLO1_ENT_018_C     BV  1414283.0  1418346.0  0.016366  0.016412
# 17  ESLO1_ENT_018_C     BV  1438347.0  1441988.0  0.016644  0.016678
# 18  ESLO1_ENT_018_C     BV  1590539.0  1593008.0  0.018403  0.018437
# 19  ESLO1_ENT_018_C     BV  1704331.0  1717361.0  0.019722  0.019873
# 20  ESLO1_ENT_018_C     BV  1939500.0  1942375.0  0.022442  0.022477
# 21  ESLO1_ENT_018_C  UF391  1946125.0  1947657.0  0.022523  0.022535
# 22  ESLO1_ENT_018_C     BV  2249189.0  2252485.0  0.026030  0.026065
# 23  ESLO1_ENT_018_C     BV  3437246.0  3442292.0  0.039780  0.039838
# 24  ESLO1_ENT_019_C     JK   158414.0   165097.0  0.001829  0.001910
# 25  ESLO1_ENT_019_C     JK   161963.0   165097.0  0.001863  0.001910
# 26  ESLO1_ENT_019_C  UG393   480961.0   484282.0  0.005556  0.005602
# 27  ESLO1_ENT_019_C     JK   590933.0   600897.0  0.006829  0.006944
# 28  ESLO1_ENT_019_C     JK   676714.0   682012.0  0.007824  0.007894
# 29  ESLO1_ENT_019_C     JK   841996.0   847457.0  0.009734  0.009803
# 30  ESLO1_ENT_019_C     JK  2077143.0  2090469.0  0.024039  0.024190
# 31  ESLO1_ENT_019_C     JK  2106289.0  2118170.0  0.024375  0.024514
# 32  ESLO1_ENT_020_C     CS    73867.0    80837.0  0.000845  0.000926
# 33  ESLO1_ENT_020_C     CS   108706.0   112775.0  0.001250  0.001296
# 34  ESLO1_ENT_020_C     CS   167425.0   174242.0  0.001933  0.002014
# 35  ESLO1_ENT_020_C     CS   947949.0   952297.0  0.010961  0.011019
# 36  ESLO1_ENT_020_C     CS  1019685.0  1026700.0  0.011794  0.011875
# 37  ESLO1_ENT_020_C     CS  1160931.0  1168571.0  0.013426  0.013519
# 38  ESLO1_ENT_020_C     CS  2036641.0  2047510.0  0.023565  0.023692
# 39  ESLO1_ENT_020_C     CS  2056097.0  2066903.0  0.023796  0.023912
# 40  ESLO1_ENT_020_C     CS  2293642.0  2307156.0  0.026539  0.026701
# 41  ESLO1_ENT_020_C     CS  2746674.0  2757501.0  0.031782  0.031910
# 42  ESLO1_ENT_020_C     CS  2775747.0  2779064.0  0.032118  0.032164
# 43  ESLO1_ENT_020_C     CS  2854673.0  2857436.0  0.033032  0.033067
# 44  ESLO1_ENT_021_C     JK    23139.0    24858.0  0.000266  0.000278
# 45  ESLO1_ENT_021_C     JK   217494.0   221815.0  0.002512  0.002558
# 46  ESLO1_ENT_021_C     JK  4474041.0  4479016.0  0.051782  0.051840
# 47  ESLO1_ENT_021_C     JK  5815527.0  5820988.0  0.067303  0.067361
# 48  ESLO1_ENT_021_C     JK  6134363.0  6140209.0  0.070995  0.071065
# 49  ESLO1_ENT_022_C     MD   225184.0   227573.0  0.002604  0.002627
# 50  ESLO1_ENT_022_C     MD   406456.0   409300.0  0.004699  0.004734
# 51  ESLO1_ENT_022_C     MD   659002.0   664140.0  0.007627  0.007685
# 52  ESLO1_ENT_022_C     MD  1343540.0  1345187.0  0.015544  0.015567
# 53  ESLO1_ENT_022_C     MD  1714702.0  1716319.0  0.019838  0.019861
# 54  ESLO1_ENT_023_C     MB   212796.0   215012.0  0.002454  0.002488
# 55  ESLO1_ENT_023_C     MB   358888.0   362062.0  0.004144  0.004190
# 56  ESLO1_ENT_023_C     MB   503893.0   505780.0  0.005822  0.005845
# 57  ESLO1_ENT_023_C     MB   529674.0   534165.0  0.006123  0.006181
# 58  ESLO1_ENT_023_C     MB   867504.0   872834.0  0.010035  0.010093
# 59  ESLO1_ENT_023_C     MB   935227.0   938940.0  0.010822  0.010856
