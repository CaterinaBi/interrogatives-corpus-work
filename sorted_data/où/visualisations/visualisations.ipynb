# %% [markdown]
# In this notebook, I'll implement some visualisation for the extracted data using matplotlib.

# %%
import pandas as pd
import matplotlib

# %%
# opens the excel sheet and reads it

file = 'où_interrogatives_global.xls'
data = pd.ExcelFile(file)

 # returns the all the sheet names within the excel file
print(data.sheet_names)
# Out:
# ['export_requete_corpus_22-08-202']

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame = data.parse('export_requete_corpus_22-08-202')
data_frame.info

# only shows the first 10 rows
data_frame.head(10)
# Out:
#    recherche occurrence       wh        int        other  \
# 0  Mot exact         où  ex situ  est-ce qu  well-formed
# 1  Mot exact         où  ex situ  est-ce qu  well-formed
# 2  Mot exact         où  ex situ  est-ce qu  well-formed
# 3  Mot exact         où  ex situ         SV  well-formed
# 4  Mot exact         où  free wh   verbless     fragment
# 5  Mot exact         où  ex situ  est-ce qu     fragment
# 6  Mot exact         où  ex situ  est-ce qu  well-formed
# 7  Mot exact         où  ex situ  est-ce qu  well-formed
# 8  Mot exact         où  ex situ         VS  well-formed
# 9  Mot exact         où  ex situ         SV  well-formed
#
#                                              segment enregistrement  \
# 0                     oui où est-ce qu'on en était ?  ESLO1_ENT_001
# 1                    où est-ce que vous les gardez ?  ESLO1_ENT_001
# 2  et euh où est-ce que vous le gardez à la maiso...  ESLO1_ENT_002
# 3                             où y a de la musique ?  ESLO1_ENT_002
# 4                                         où ? ici ?  ESLO1_ENT_003
# 5                               oui et où est-ce que  ESLO1_ENT_005
# 6                    où est-ce que vous les gardez ?  ESLO1_ENT_005
# 7       deux volumes où est-ce que vous les gardez ?  ESLO1_ENT_006
# 8                et où gardez-vous ce dictionnaire ?  ESLO1_ENT_007
# 9  où irait le français si le français n'avait pa...  ESLO1_ENT_007
#
#      transcription locuteur  debut (ms)   fin (ms) debut (hh:mm:ss)  \
# 0  ESLO1_ENT_001_C    BA725     1430386  1431464.0         00:23:50
# 1  ESLO1_ENT_001_C       OU     2424703  2425691.0         00:40:24
# 2  ESLO1_ENT_002_C       JR       66273    69640.0         00:01:06
# 3  ESLO1_ENT_002_C       JR     1015263  1016117.0         00:16:55
# 4  ESLO1_ENT_003_C     DJ39       28634    29306.0         00:00:28
# 5  ESLO1_ENT_005_C       PB     2287721  2291580.0         00:38:07
# 6  ESLO1_ENT_005_C       PB     2290143  2291580.0         00:38:10
# 7  ESLO1_ENT_006_C       JK     1881173  1884426.0         00:31:21
# 8  ESLO1_ENT_007_C       RC     2002487  2004519.0         00:33:22
# 9  ESLO1_ENT_007_C    FU200     2838929  2841795.0         00:47:18
#
#   fin (hh:mm:ss)
# 0       00:23:51
# 1       00:40:25
# 2       00:01:09
# 3       00:16:56
# 4       00:00:29
# 5       00:38:11
# 6       00:38:11
# 7       00:31:24
# 8       00:33:24
# 9       00:47:21

# %% [markdown]
# I will now utilise matplotlib to create visualisations for my data.
# This first part will be about global visualisations of data (both corpora combined).

# %%
rows =
