# %% [markdown]
# Visualisations for Baunaz & Bonan (2023)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# Figure 1: proportion of ex situ vs in situ over time

# %%
plt.rcParams["figure.figsize"] = [4.00, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['ESLO 1', 'ESLO 2']

# data
ex_situ = [81, 38]
in_situ = [19, 62]

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, ex_situ, width, color='gainsboro', label='ex situ')
rects2 = ax.bar(x + width/2, in_situ, width, color='silver', label='in situ')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences')
ax.set_xlabel('Corpora')
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()
