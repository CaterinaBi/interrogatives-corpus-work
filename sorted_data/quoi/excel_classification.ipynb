# %% [markdown]
# This code is to classify the selected examples automatically for those criteria that allow automatic classification.

# %%
import pandas as pd
import xlrd
import re
from re import search

# %%
# opens the excel sheet and reads it
# excel sheet needs to be in the same working directory as this file

file = 'quoi_selected_rows_sorted.xls'
data = pd.ExcelFile(file)

# returns the all the sheet names within the excel file
print(data.sheet_names)
# Out:
# ['Sheet1']

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame = data.parse('Sheet1')
data_frame.info

# only shows the first 10 rows
data_frame.head(10)
# Out:
#            0     1  wh  int  other  \
# 0  Mot exact  quoi NaN  NaN    NaN
# 1  Mot exact  quoi NaN  NaN    NaN
# 2  Mot exact  quoi NaN  NaN    NaN
# 3  Mot exact  quoi NaN  NaN    NaN
# 4  Mot exact  quoi NaN  NaN    NaN
# 5  Mot exact  quoi NaN  NaN    NaN
# 6  Mot exact  quoi NaN  NaN    NaN
# 7  Mot exact  quoi NaN  NaN    NaN
# 8  Mot exact  quoi NaN  NaN    NaN
# 9  Mot exact  quoi NaN  NaN    NaN
#
#                                                    9              2  \
# 0  est-ce que vous pouvez me dire euh en quoi ça ...  ESLO1_ENT_001
# 1        en quoi est-ce que ça consiste exactement ?  ESLO1_ENT_001
# 2  de mieux en mieux oui et à quoi cela tient d'a...  ESLO1_ENT_001
# 3  et le le fait que l'orthographe soit mieux ens...  ESLO1_ENT_001
# 4  et un une autre matière deuxième matière aurai...  ESLO1_ENT_001
# 5                             euh quoi par exemple ?  ESLO1_ENT_001
# 6                                de quoi s'agit-il ?  ESLO1_ENT_002
# 7                        et vous écrivez avec quoi ?  ESLO1_ENT_002
# 8                                          la quoi ?  ESLO1_ENT_002
# 9                            c'est quoi exactement ?  ESLO1_ENT_002
#
#                  3   4        5          6         7         8
# 0  ESLO1_ENT_001_C  OU   217697   222152.0  0.002512  0.002569
# 1  ESLO1_ENT_001_C  OU   299545   301282.0  0.003461  0.003484
# 2  ESLO1_ENT_001_C  OU  2786889  2789314.0  0.032245  0.032280
# 3  ESLO1_ENT_001_C  OU  3026630  3030133.0  0.035023  0.035069
# 4  ESLO1_ENT_001_C  OU  3059914  3062962.0  0.035405  0.035440
# 5  ESLO1_ENT_001_C  OU  3606863  3607971.0  0.041736  0.041748
# 6  ESLO1_ENT_002_C  JR   274971   276383.0  0.003171  0.003194
# 7  ESLO1_ENT_002_C  JR   510327   512058.0  0.005903  0.005926
# 8  ESLO1_ENT_002_C  JR  2384465  2385423.0  0.027593  0.027604
# 9  ESLO1_ENT_002_C  JR  2823321  2824542.0  0.032674  0.032685

# %%
# reads in the spreadsheet data

workbook = xlrd.open_workbook('quoi_selected_rows_sorted.xls')
sheet = workbook.sheet_by_name('Sheet1')

row_count = sheet.nrows
col_count = sheet.ncols
print(f'Total rows: {row_count}\nTotal columns: {col_count}')
# Out:
# Total rows: 2359
# Total columns: 13

# %% [markdown]
# We're now going to create a new list of lists out of the file, and populate the empty columns with as much data as possible.
#
# The data that should be easy to classify automatically are: est-ce que / wh- at the beginning or end of sentence / presence of c'est.

# %%
# initialises list of lists
all_rows = []
unwanted_segment = 'n\'importe\squoi'
# unwanted_segment2 = 'quoi\sfaire'
unwanted_segment3 = 'ou\squoi'

for rx in range(sheet.nrows): # rx is an int, row is a list 
    row = sheet.row(rx)
    
    # initialises list that will contain our data
    data_list = []

    # populates list that stores all rows
    data_list.append(row[0].value)
    data_list.append(row[1].value)
    data_list.append(row[2].value) # wh
    data_list.append(row[3].value) # int
    data_list.append(row[4].value) # other
    # excludes all utterances containing 'qu'est-ce qui'
    utterance = str(row[5].value)
    if search(unwanted_segment, utterance) or search(unwanted_segment3, utterance):
        # excludes unwanted segments
        # print(utterance)
        continue
    else:
        data_list.append(utterance) # segment
    data_list.append(row[6].value)
    data_list.append(row[7].value)
    data_list.append(row[8].value)
    data_list.append(row[9].value)
    data_list.append(row[10].value)
    data_list.append(row[11].value)
    data_list.append(row[12].value)

    all_rows.append(data_list)
        
# prints extracted rows metrics
print(f'We created a list that embeds {len(all_rows)} lists.')
# Out:
# We created a list that embeds 2309 lists.

# %%
# iterates through list of lists and populates empty cells

indirect_object_count = 0

string = 'est-ce\sque'
stringb = 'est-ce\squ\''
string_count = 0
io_quoi = ['de quoi', 'en quoi', 'à quoi', 'pour quoi', 'avec quoi', 'par quoi', 'sur quoi']

string2 = 'c\'est\squoi'
string2_count = 0

ex_situ_count = 0
in_situ_count = 0
fragment_count = 0
sv_count = 0

for list in all_rows:
    
    text = list[5] # index 5 is where text of interest is stored, returns a cell

    # classifies sentence as IO
    for wh in io_quoi:
        if wh in text:
            list[1] = 'quoiIO'
            indirect_object_count += 1

    if search(string, text) or search(stringb, text):
        list[2] = 'ex situ'
        list[3] = 'est-ce que'
        list[4] = 'formed' # then check manually and change to 'fragment' if needed
        string_count += 1
    
    if search(string2, text):
        list[2] = 'in situ'
        list[3] = 'cleft'
        if 'que' in text or 'qu\'' in text:
            list[4] = 'bi'
        else:
            list[4] = 'mono'
        string2_count += 1

    if re.search('^de\squoi\s', text, flags=0) or re.search('^et\sde\squoi\s', text, flags=0) or re.search('^alors\sde\squoi\s', text, flags=0) or re.search('^et\salors\sde\squoi\s', text, flags=0) or re.search('^en\squoi\s', text, flags=0) or re.search('^et\sen\squoi\s', text, flags=0) or re.search('^alors\sen\squoi\s', text, flags=0) or re.search('^et\salors\sen\squoi\s', text, flags=0) or re.search('^à\squoi\s', text, flags=0) or re.search('^et\sà\squoi\s', text, flags=0) or re.search('^alors\sà\squoi\s', text, flags=0) or re.search('^et\salors\sà\squoi\s', text, flags=0) or re.search('^pour\squoi\s', text, flags=0) or re.search('^et\spour\squoi\s', text, flags=0) or re.search('^alors\spour\squoi\s', text, flags=0) or re.search('^et\salors\spour\squoi\s', text, flags=0) or re.search('^avec\squoi\s', text, flags=0) or re.search('^et\savec\squoi\s', text, flags=0) or re.search('^alors\savec\squoi\s', text, flags=0) or re.search('^et\salors\savec\squoi\s', text, flags=0) or re.search('^par\squoi\s', text, flags=0) or re.search('^et\spar\squoi\s', text, flags=0) or re.search('^alors\spar\squoi\s', text, flags=0) or re.search('^et\salors\spar\squoi\s', text, flags=0) or re.search('^sur\squoi\s', text, flags=0) or re.search('^et\ssur\squoi\s', text, flags=0) or re.search('^alors\ssur\squoi\s', text, flags=0) or re.search('^et\salors\ssur\squoi\s', text, flags=0):
        list[2] = 'ex situ'
        list[4] = 'formed' # then check manually and change to 'fragment' if needed
        ex_situ_count += 1

        if text.endswith('quoi ?') or text.endswith('quoi ça ?') or text.endswith('quoi alors ?'):
            list[2] = 'wh'
            list[3] = 'none'
            list[4] = 'fragment'
            fragment_count += 1
        elif re.search('quoi\sje', text, flags=0) or re.search('quoi\stu', text, flags=0) or re.search('quoi\selle', text, flags=0) or re.search('quoi\sil', text, flags=0) or re.search('quoi\snous', text, flags=0) or re.search('quoi\svous', text, flags=0) or re.search('quoi\selles', text, flags=0) or re.search('quoi\sils', text, flags=0) or re.search('quoi\sça', text, flags=0) or re.search('quoi\son', text, flags=0):
            list[3] = 'SV'
            list[4] = 'formed'
            sv_count += 1
        elif re.search('^quoi\squ\'', text, flags=0):
            list[3] = 'que'

    elif text.endswith('quoi ?'):
        list[2] = 'in situ'
        list[3] = 'SV'
        list[4] = 'final'
        in_situ_count += 1
        
    elif text.endswith('quoi alors ?') or text.endswith('quoi ça ?') or text.endswith('quoi madame ?') or text.endswith('quoi monsieur ?') or text.endswith('quoi vous ?'):
        list[2] = 'in situ'
        list[3] = 'SV'
        list[4] = 'non final'
        in_situ_count += 1

# print metrics
print(f'{indirect_object_count} occurrences of indirect object \'quoi\' found.')
print(f'{string_count} occurrences of \'est-ce que\' found.')
print(f'{string2_count} occurrences of \'c\'est\' found.')
print(f'{ex_situ_count} occurrences of \'quoi\' ex situ found.')
print(f'{in_situ_count} occurrences of \'quoi\' in situ found.')
print(f'{fragment_count} occurrences of fragments found.')
print(f'{sv_count} occurrences of SV ordering found.')
# Out:
# 922 occurrences of indirect object 'quoi' found.
# 189 occurrences of 'est-ce que' found.
# 348 occurrences of 'c'est' found.
# 416 occurrences of 'quoi' ex situ found.
# 979 occurrences of 'quoi' in situ found.
# 112 occurrences of fragments found.
# 71 occurrences of SV ordering found.

# %% [markdown]
# We will now create a new .xlsx file with all the classified data.

# %%
# creates spreadsheet using each nested list as a row

df = pd.DataFrame(data=all_rows)

# converts into excel
df.to_excel("quoi_all_rows_classified.xlsx", index=False)

print("Dictionary converted into excel...")
# Out:
# Dictionary converted into excel...

# %%
# opens the new excel file and reads it

file2 = 'quoi_all_rows_classified.xls'
data2 = pd.ExcelFile(file2)

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame2 = data2.parse('Sheet1')
data_frame2.info

# only shows the first 60 rows
data_frame2.head(60)
# Out:
#            0       1        2           3         4   \
# 0           0       1       wh         int     other
# 1   Mot exact  quoiIO  ex situ  est-ce que    formed
# 2   Mot exact  quoiIO  ex situ  est-ce que    formed
# 3   Mot exact  quoiIO      NaN         NaN       NaN
# 4   Mot exact  quoiIO      NaN         NaN       NaN
# 5   Mot exact    quoi  in situ          SV     final
# 6   Mot exact    quoi      NaN         NaN       NaN
# 7   Mot exact  quoiIO  ex situ         NaN    formed
# 8   Mot exact  quoiIO  in situ          SV     final
# 9   Mot exact    quoi  in situ          SV     final
# 10  Mot exact    quoi  in situ       cleft      mono
# 11  Mot exact    quoi  in situ       cleft        bi
# 12  Mot exact    quoi      NaN         NaN       NaN
# 13  Mot exact    quoi      NaN         NaN       NaN
# 14  Mot exact    quoi  in situ          SV     final
# 15  Mot exact    quoi      NaN         NaN       NaN
# 16  Mot exact  quoiIO  ex situ         NaN    formed
# 17  Mot exact  quoiIO  in situ          SV     final
# 18  Mot exact    quoi  in situ          SV     final
# 19  Mot exact    quoi      NaN         NaN       NaN
# 20  Mot exact  quoiIO      NaN         NaN       NaN
# 21  Mot exact    quoi      NaN         NaN       NaN
# 22  Mot exact    quoi      NaN         NaN       NaN
# 23  Mot exact  quoiIO  ex situ         NaN    formed
# 24  Mot exact  quoiIO  ex situ         NaN    formed
# 25  Mot exact    quoi  ex situ  est-ce que    formed
# 26  Mot exact    quoi  in situ       cleft        bi
# 27  Mot exact  quoiIO  ex situ         NaN    formed
# 28  Mot exact  quoiIO  ex situ         NaN    formed
# 29  Mot exact    quoi  in situ          SV     final
# 30  Mot exact    quoi  in situ          SV     final
# 31  Mot exact  quoiIO  in situ          SV     final
# 32  Mot exact  quoiIO  ex situ         NaN    formed
# 33  Mot exact  quoiIO  ex situ          SV    formed
# 34  Mot exact    quoi  in situ          SV     final
# 35  Mot exact  quoiIO  ex situ         NaN    formed
# 36  Mot exact  quoiIO       wh        none  fragment
# 37  Mot exact  quoiIO  ex situ  est-ce que    formed
# 38  Mot exact    quoi  in situ       cleft      mono
# 39  Mot exact    quoi  in situ       cleft      mono
# 40  Mot exact    quoi  in situ          SV     final
# 41  Mot exact    quoi  in situ          SV     final
# 42  Mot exact    quoi  in situ          SV     final
# 43  Mot exact    quoi  in situ          SV     final
# 44  Mot exact  quoiIO       wh        none  fragment
# 45  Mot exact    quoi      NaN         NaN       NaN
# 46  Mot exact    quoi      NaN         NaN       NaN
# 47  Mot exact  quoiIO  in situ          SV     final
# 48  Mot exact    quoi  in situ          SV     final
# 49  Mot exact    quoi  in situ          SV     final
# 50  Mot exact    quoi  in situ          SV     final
# 51  Mot exact    quoi  in situ       cleft      mono
# 52  Mot exact    quoi  in situ       cleft      mono
# 53  Mot exact    quoi      NaN         NaN       NaN
# 54  Mot exact  quoiIO  in situ          SV     final
# 55  Mot exact    quoi      NaN         NaN       NaN
# 56  Mot exact    quoi  in situ          SV     final
# 57  Mot exact  quoiIO  ex situ          SV    formed
# 58  Mot exact  quoiIO      NaN         NaN       NaN
# 59  Mot exact  quoiIO      NaN         NaN       NaN
#
#                                                    5              6   \
# 0                                                 9.0              2
# 1   est-ce que vous pouvez me dire euh en quoi ça ...  ESLO1_ENT_001
# 2         en quoi est-ce que ça consiste exactement ?  ESLO1_ENT_001
# 3   de mieux en mieux oui et à quoi cela tient d'a...  ESLO1_ENT_001
# 4   et le le fait que l'orthographe soit mieux ens...  ESLO1_ENT_001
# 5   et un une autre matière deuxième matière aurai...  ESLO1_ENT_001
# 6                              euh quoi par exemple ?  ESLO1_ENT_001
# 7                                 de quoi s'agit-il ?  ESLO1_ENT_002
# 8                         et vous écrivez avec quoi ?  ESLO1_ENT_002
# 9                                           la quoi ?  ESLO1_ENT_002
# 10                            c'est quoi exactement ?  ESLO1_ENT_002
# 11         mais c'est quoi au juste comme technique ?  ESLO1_ENT_002
# 12  voyez-vous ? c'est resté encore le petit provi...  ESLO1_ENT_002
# 13  eh bien je suis persuadé qu'au bout de qu'au b...  ESLO1_ENT_002
# 14                                         euh quoi ?  ESLO1_ENT_003
# 15                              euh quoi exactement ?  ESLO1_ENT_003
# 16  à quoi est-ce qu'on reconnaît une enfin un mem...  ESLO1_ENT_005
# 17                             et cela tient à quoi ?  ESLO1_ENT_005
# 18                                             quoi ?  ESLO1_ENT_005
# 19                        quoi comment comment cela ?  ESLO1_ENT_005
# 20  euh avec quel écrivez-vous lorsque vous écrive...  ESLO1_ENT_005
# 21                                  quoi exactement ?  ESLO1_ENT_005
# 22                                   et quoi encore ?  ESLO1_ENT_006
# 23      en quoi portent-elles portent-elles surtout ?  ESLO1_ENT_006
# 24                   et de quoi cela vient-il alors ?  ESLO1_ENT_006
# 25  avec euh quoi est-ce que vous écrivez alors st...  ESLO1_ENT_006
# 26     c'est quoi au juste ce que vous faites au en ?  ESLO1_ENT_007
# 27    et à quoi est-ce qu'on reconnait un bourgeois ?  ESLO1_ENT_007
# 28              et en quoi consistent-elles surtout ?  ESLO1_ENT_007
# 29                                             quoi ?  ESLO1_ENT_007
# 30                                             quoi ?  ESLO1_ENT_007
# 31                                c'était pour quoi ?  ESLO1_ENT_007
# 32                        et avec quoi écrivez-vous ?  ESLO1_ENT_007
# 33                           et en quoi ça consiste ?  ESLO1_ENT_008
# 34  la population mais la population en général qu...  ESLO1_ENT_008
# 35  et à quoi est-ce qu'on reconnaît par exemple u...  ESLO1_ENT_008
# 36                                   par quoi alors ?  ESLO1_ENT_008
# 37  et et de quoi est-ce que vous parlez en général ?  ESLO1_ENT_008
# 38                               c'est quoi donc ça ?  ESLO1_ENT_008
# 39                               c'est quoi donc ça ?  ESLO1_ENT_008
# 40                                             quoi ?  ESLO1_ENT_008
# 41                                             quoi ?  ESLO1_ENT_008
# 42                                             quoi ?  ESLO1_ENT_008
# 43                         et c'est pour faire quoi ?  ESLO1_ENT_008
# 44                                         sur quoi ?  ESLO1_ENT_010
# 45                  ben oui mais quoi faire d'autre ?  ESLO1_ENT_010
# 46                             quoi ? y a tout dedans  ESLO1_ENT_010
# 47           et c'était pour quelle oc- ? pour quoi ?  ESLO1_ENT_010
# 48                       que vous les grondiez quoi ?  ESLO1_ENT_010
# 49                                 privé aussi quoi ?  ESLO1_ENT_010
# 50                                alors modéré quoi ?  ESLO1_ENT_010
# 51            au fait le le TVA c'est quoi au juste ?  ESLO1_ENT_011
# 52  et c'est quoi au juste ? c'est une sorte de re...  ESLO1_ENT_011
# 53   on parle quoi actuellement ? on parle le Fortran  ESLO1_ENT_012
# 54  à l'école il y a des des enfants qui réussisse...  ESLO1_ENT_013
# 55  vous pensez quand même qu'il serait bon qu'un ...  ESLO1_ENT_013
# 56  hein ? est-ce que vous pourriez décrire enfin ...  ESLO1_ENT_013
# 57             à quoi vous le reconnaissez celui-là ?  ESLO1_ENT_013
# 58    et à votre avis ça va ça porte sur quoi enfin ?  ESLO1_ENT_013
# 59                     ça tient à quoi d'après vous ?  ESLO1_ENT_013
#
#                  7       8        9          10        11        12
# 0                 3       4        5        6.0  7.000000  8.000000
# 1   ESLO1_ENT_001_C      OU   217697   222152.0  0.002512  0.002569
# 2   ESLO1_ENT_001_C      OU   299545   301282.0  0.003461  0.003484
# 3   ESLO1_ENT_001_C      OU  2786889  2789314.0  0.032245  0.032280
# 4   ESLO1_ENT_001_C      OU  3026630  3030133.0  0.035023  0.035069
# 5   ESLO1_ENT_001_C      OU  3059914  3062962.0  0.035405  0.035440
# 6   ESLO1_ENT_001_C      OU  3606863  3607971.0  0.041736  0.041748
# 7   ESLO1_ENT_002_C      JR   274971   276383.0  0.003171  0.003194
# 8   ESLO1_ENT_002_C      JR   510327   512058.0  0.005903  0.005926
# 9   ESLO1_ENT_002_C      JR  2384465  2385423.0  0.027593  0.027604
# 10  ESLO1_ENT_002_C      JR  2823321  2824542.0  0.032674  0.032685
# 11  ESLO1_ENT_002_C      JR  3660287  3662397.0  0.042361  0.042384
# 12  ESLO1_ENT_002_C   DE744  4778347  4785799.0  0.055301  0.055382
# 13  ESLO1_ENT_002_C   DE744  4892040  4901913.0  0.056620  0.056725
# 14  ESLO1_ENT_003_C      JR  2693832  2694676.0  0.031169  0.031181
# 15  ESLO1_ENT_003_C      JR  2760797  2763907.0  0.031944  0.031979
# 16  ESLO1_ENT_005_C      PB  2105026  2109638.0  0.024363  0.024410
# 17  ESLO1_ENT_005_C      PB  2873623  2880591.0  0.033252  0.033333
# 18  ESLO1_ENT_005_C      PB  3134382  3135508.0  0.036273  0.036285
# 19  ESLO1_ENT_005_C      PB  3612665  3614009.0  0.041806  0.041829
# 20  ESLO1_ENT_005_C      PB  3630981  3634587.0  0.042014  0.042060
# 21  ESLO1_ENT_005_C      PB  3808297  3810921.0  0.044074  0.044097
# 22  ESLO1_ENT_006_C      JK   683671   684343.0  0.007905  0.007917
# 23  ESLO1_ENT_006_C      JK  2372985  2375923.0  0.027454  0.027488
# 24  ESLO1_ENT_006_C      JK  2517594  2519530.0  0.029132  0.029155
# 25  ESLO1_ENT_006_C      JK  3409125  3412774.0  0.039456  0.039491
# 26  ESLO1_ENT_007_C      RC   105887   108059.0  0.001215  0.001250
# 27  ESLO1_ENT_007_C      RC  1005781  1008452.0  0.011632  0.011667
# 28  ESLO1_ENT_007_C      RC  2368425  2374344.0  0.027407  0.027477
# 29  ESLO1_ENT_007_C      RC  2704029  2705702.0  0.031296  0.031308
# 30  ESLO1_ENT_007_C   FU200  2705702  2713247.0  0.031308  0.031400
# 31  ESLO1_ENT_007_C      RC  2761844  2763585.0  0.031956  0.031979
# 32  ESLO1_ENT_007_C      RC  3118560  3120258.0  0.036088  0.036111
# 33  ESLO1_ENT_008_C      RC    44043    45836.0  0.000509  0.000521
# 34  ESLO1_ENT_008_C   GJ131   802998   805992.0  0.009282  0.009317
# 35  ESLO1_ENT_008_C      RC   824748   828203.0  0.009537  0.009583
# 36  ESLO1_ENT_008_C      RC   839922   841155.0  0.009711  0.009734
# 37  ESLO1_ENT_008_C      RC  1000476  1002804.0  0.011574  0.011597
# 38  ESLO1_ENT_008_C   GJ131  1467886  1471983.0  0.016979  0.017025
# 39  ESLO1_ENT_008_C   GJ131  1470793  1471983.0  0.017014  0.017025
# 40  ESLO1_ENT_008_C      RC  2034831  2035268.0  0.023542  0.023553
# 41  ESLO1_ENT_008_C      RC  2052880  2053332.0  0.023750  0.023762
# 42  ESLO1_ENT_008_C      RC  2517768  2518049.0  0.029132  0.029144
# 43  ESLO1_ENT_008_C      RC  2581254  2582442.0  0.029873  0.029884
# 44  ESLO1_ENT_010_C      MB  2473260  2473833.0  0.028623  0.028623
# 45  ESLO1_ENT_010_C  010LOC  2847838  2849043.0  0.032951  0.032975
# 46  ESLO1_ENT_010_C      MB  4456716  4457937.0  0.051574  0.051586
# 47  ESLO1_ENT_010_C      MB  5365701  5367494.0  0.062095  0.062118
# 48  ESLO1_ENT_010_C      MB  6126953  6127931.0  0.070903  0.070914
# 49  ESLO1_ENT_010_C      MB  6726294  6727524.0  0.077847  0.077859
# 50  ESLO1_ENT_010_C      MB  7178965  7180253.0  0.083079  0.083102
# 51  ESLO1_ENT_011_C      JK  1554371  1565798.0  0.017986  0.018113
# 52  ESLO1_ENT_011_C   JW325  2162156  2165859.0  0.025023  0.025058
# 53  ESLO1_ENT_012_C   LD386  4106505  4110521.0  0.047523  0.047569
# 54  ESLO1_ENT_013_C      BV   871599   876464.0  0.010081  0.010139
# 55  ESLO1_ENT_013_C      BV  1062707  1073290.0  0.012292  0.012419
# 56  ESLO1_ENT_013_C      BV  1288154  1297513.0  0.014907  0.015012
# 57  ESLO1_ENT_013_C      BV  1598734  1600337.0  0.018495  0.018519
# 58  ESLO1_ENT_013_C      BV  2152854  2158940.0  0.024907  0.024977
# 59  ESLO1_ENT_013_C      BV  2729400  2730478.0  0.031586  0.031597
