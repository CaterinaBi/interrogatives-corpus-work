# %% [markdown]
# This code is to classify the selected examples automatically for those criteria that allow automatic classification.

# %%
import pandas as pd
import xlrd
import re
from re import search

# %%
# opens the excel sheet and reads it
# excel sheet needs to be in the same working directory as this file

file = 'qui_selected_rows_sorted.xls'
data = pd.ExcelFile(file)

# returns the all the sheet names within the excel file
print(data.sheet_names)
# Out:
# ['Sheet1']

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame = data.parse('Sheet1')
data_frame.info

# only shows the first 10 rows
data_frame.head(10)
# Out:
#    recherche occurrence  wh  int  other  \
# 0  Mot exact        qui NaN  NaN    NaN
# 1  Mot exact        qui NaN  NaN    NaN
# 2  Mot exact        qui NaN  NaN    NaN
# 3  Mot exact        qui NaN  NaN    NaN
# 4  Mot exact        qui NaN  NaN    NaN
# 5  Mot exact        qui NaN  NaN    NaN
# 6  Mot exact        qui NaN  NaN    NaN
# 7  Mot exact        qui NaN  NaN    NaN
# 8  Mot exact        qui NaN  NaN    NaN
# 9  Mot exact        qui NaN  NaN    NaN
#
#                                              segment enregistrement  \
# 0               trés bien qui habitent la rue hein ?  ESLO1_ENT_017
# 1                           qui habitent le ah bon ?  ESLO1_ENT_017
# 2  qu'est-ce qui vous plaît et qu'est-ce qui vous...  ESLO1_ENT_017
# 3  quelles sont les choses qui vous plaisent le p...  ESLO1_ENT_017
# 4  qu'est-ce que vous pensez des des femmes marié...  ESLO1_ENT_017
# 5      qu'est-ce qui leur plaît dans leurs loisirs ?  ESLO1_ENT_017
# 6  alors à Orléans qui est-ce qui va à la maison ...  ESLO1_ENT_017
# 7  à votre avis qu'est-ce qui fait que les enfant...  ESLO1_ENT_017
# 8  quelles sont les p- les personnes qui comptent...  ESLO1_ENT_017
# 9  vous pouvez expliquer un peu ce qui s'est passé ?  ESLO1_ENT_017
#
#      transcription locuteur  debut (ms)   fin (ms)  debut (hh:mm:ss)  \
# 0  ESLO1_ENT_017_C    QB100     97160.0    98641.0          0.001123
# 1  ESLO1_ENT_017_C       CS    370289.0   371481.0          0.004282
# 2  ESLO1_ENT_017_C       CS    730114.0   738206.0          0.008449
# 3  ESLO1_ENT_017_C       CS    734543.0   738206.0          0.008495
# 4  ESLO1_ENT_017_C       CS    768372.0   772569.0          0.008889
# 5  ESLO1_ENT_017_C    QB100   1031781.0  1038519.0          0.011933
# 6  ESLO1_ENT_017_C       CS   1062853.0  1065278.0          0.012292
# 7  ESLO1_ENT_017_C       CS   1366299.0  1373565.0          0.015810
# 8  ESLO1_ENT_017_C       CS   1859247.0  1864205.0          0.021516
# 9  ESLO1_ENT_017_C       CS   2026649.0  2038217.0          0.023449
#
#    fin (hh:mm:ss)
# 0        0.001134
# 1        0.004294
# 2        0.008542
# 3        0.008542
# 4        0.008935
# 5        0.012014
# 6        0.012326
# 7        0.015891
# 8        0.021574
# 9        0.023588

# %%
# reads in the spreadsheet data

workbook = xlrd.open_workbook('qui_selected_rows_sorted.xls')
sheet = workbook.sheet_by_name('Sheet1')

row_count = sheet.nrows
col_count = sheet.ncols
print(f'Total rows: {row_count}\nTotal columns: {col_count}')
# Out:
# Total rows: 3162
# Total columns: 13

# %% [markdown]
# We're now going to create a new list of lists out of the file, and populate the empty columns with as much data as possible.
#
# The data that should be easy to classify automatically are: est-ce que / wh- at the beginning or end of sentence / presence of c'est.

# %%
# initialises list of lists
all_rows = []
unwanted_segment = 'qu\'est-ce\squi'

for rx in range(sheet.nrows): # rx is an int, row is a list 
    row = sheet.row(rx)
    
    # initialises list that will contain our data
    data_list = []

    # populates list that stores all rows
    data_list.append(row[0].value)
    data_list.append(row[1].value)
    data_list.append(row[2].value) # wh
    data_list.append(row[3].value) # int
    data_list.append(row[4].value) # other
    # excludes all utterances containing 'qu'est-ce qui'
    utterance = row[5].value
    if search(unwanted_segment, utterance):
        # excludes unwanted segments
        continue
    else:
        data_list.append(utterance) # segment
    data_list.append(row[6].value)
    data_list.append(row[7].value)
    data_list.append(row[8].value)
    data_list.append(row[9].value)
    data_list.append(row[10].value)
    data_list.append(row[11].value)
    data_list.append(row[12].value)

    all_rows.append(data_list)
        
# prints extracted rows metrics
print(f'We created a list that embeds {len(all_rows)} lists.')
# Out:
# We created a list that embeds 2656 lists.

# %%
# iterates through list of lists and populates empty cells

subject = 'qui\sest-ce\squi'
direct_object = 'qui\sest-ce\sque'
subject2 = 'qui\sc\'est\squi'
direct_object2 = 'qui\sc\'est\squé'
subject3 = 'c\'est\squi\squi'
direct_object3 = 'c\'est\squi\sque'

subject_count = 0
direct_object_count = 0

string = 'est-ce'
string_count = 0
string2 = 'c\'est\squi'
string2b = 'qui\sc\'est'
string2_count = 0

ex_situ_count = 0
in_situ_count = 0
fragment_count = 0
sv_count = 0

for list in all_rows:
    
    text = list[5] # index 5 is where text of interest is stored, returns a cell

    # checks whether 'qui' is S or DO
    if search(subject, text) or search(subject2, text) or search(subject3, text):
        list[1] = 'quiS'
        subject_count += 1
    elif search(direct_object, text) or search(direct_object2, text) or search(direct_object3, text):
        list[1] = 'quiDO'
        direct_object_count += 1

    if search(string, text):
        list[2] = 'ex situ'
        list[3] = 'est-ce que'
        list[4] = 'formed' # then check manually and change to 'fragment' if needed
        string_count += 1
    elif search(string2, text) or search(string2b, text):
        list[3] = 'cleft'

        if search(string2, text):
            list[2] = 'in situ'
        elif search(string2b, text):
            list[2] = 'ex situ'
        string2_count += 1

    if re.search('^qui\s', text, flags=0) or re.search('^et\squi\s', text, flags=0) or re.search('^alors\squi\s', text, flags=0) or re.search('^et\salors\squi\s', text, flags=0):
        list[2] = 'ex situ'
        list[4] = 'formed' # then check manually and change to 'fragment' if needed
        ex_situ_count += 1

        if search(string2, text) or search(string2b, text):
            list[3] = 'cleft'
        elif text.endswith('qui ?') or text.endswith('qui ça ?') or text.endswith('qui alors ?'):
            list[2] = 'wh'
            list[3] = 'none'
            list[4] = 'fragment'
            fragment_count += 1
        elif re.search('^qui\sje', text, flags=0) or re.search('^qui\stu', text, flags=0) or re.search('^qui\selle', text, flags=0) or re.search('^qui\sil', text, flags=0) or re.search('^qui\snous', text, flags=0) or re.search('^qui\svous', text, flags=0) or re.search('^qui\selles', text, flags=0) or re.search('^qui\sils', text, flags=0) or re.search('^qui\sça', text, flags=0) or re.search('^qui\son', text, flags=0):
            list[3] = 'SV'
            list[4] = 'formed'
            sv_count += 1
        elif re.search('^qui\sje', text, flags=0):
            list[3] = 'que'

    elif text.endswith('qui ?'):
        list[2] = 'in situ'
        list[3] = 'SV'
        list[4] = 'final'
        in_situ_count += 1
        
    elif text.endswith('qui alors ?') or text.endswith('qui ça ?') or text.endswith('qui madame ?') or text.endswith('qui monsieur ?') or text.endswith('qui vous ?'):
        list[2] = 'in situ'
        list[3] = 'SV'
        list[4] = 'non final'
        in_situ_count += 1

# print metrics
print(f'{subject_count} occurrences of subject \'qui\' found.')
print(f'{direct_object_count} occurrences of direct object \'qui\' found.')
print(f'{string_count} occurrences of \'est-ce que\' found.')
print(f'{string2_count} occurrences of \'c\'est\' found.')
print(f'{ex_situ_count} occurrences of \'qui\' ex situ found.')
print(f'{in_situ_count} occurrences of \'qui\' in situ found.')
print(f'{fragment_count} occurrences of fragments found.')
print(f'{sv_count} occurrences of SV ordering found.')
# Out:
# 229 occurrences of subject 'qui' found.
# 15 occurrences of direct object 'qui' found.
# 697 occurrences of 'est-ce que' found.
# 114 occurrences of 'c'est' found.
# 703 occurrences of 'qui' ex situ found.
# 112 occurrences of 'qui' in situ found.
# 25 occurrences of fragments found.
# 54 occurrences of SV ordering found.

# %% [markdown]
# We will now create a new .xlsx file with all the classified data.

# %%
# creates spreadsheet using each nested list as a row

df = pd.DataFrame(data=all_rows)

# converts into excel
df.to_excel("qui_all_rows_classified.xlsx", index=False)

print("Dictionary converted into excel...")
# Out:
# Dictionary converted into excel...

# %%
# opens the new excel file and reads it

file2 = 'qui_all_rows_classified.xls'
data2 = pd.ExcelFile(file2)

# %%
# parses the sheet into a data frame to show the column structure within the file

data_frame2 = data2.parse('Sheet1')
data_frame2.info

# only shows the first 60 rows
data_frame2.head(60)
# Out:
#            0           1        2           3       4   \
# 0   recherche  occurrence       wh         int   other
# 1   Mot exact         qui      NaN         NaN     NaN
# 2   Mot exact         qui  ex situ         NaN  formed
# 3   Mot exact         qui      NaN         NaN     NaN
# 4   Mot exact         qui  ex situ  est-ce que  formed
# 5   Mot exact        quiS  ex situ  est-ce que  formed
# 6   Mot exact         qui      NaN         NaN     NaN
# 7   Mot exact         qui      NaN         NaN     NaN
# 8   Mot exact         qui      NaN         NaN     NaN
# 9   Mot exact         qui  ex situ  est-ce que  formed
# 10  Mot exact         qui  ex situ  est-ce que  formed
# 11  Mot exact         qui  ex situ  est-ce que  formed
# 12  Mot exact         qui      NaN         NaN     NaN
# 13  Mot exact         qui      NaN         NaN     NaN
# 14  Mot exact         qui      NaN         NaN     NaN
# 15  Mot exact         qui  ex situ  est-ce que  formed
# 16  Mot exact         qui  ex situ  est-ce que  formed
# 17  Mot exact         qui  ex situ  est-ce que  formed
# 18  Mot exact         qui  ex situ         NaN  formed
# 19  Mot exact         qui      NaN         NaN     NaN
# 20  Mot exact         qui      NaN         NaN     NaN
# 21  Mot exact         qui      NaN         NaN     NaN
# 22  Mot exact         qui      NaN         NaN     NaN
# 23  Mot exact         qui  ex situ  est-ce que  formed
# 24  Mot exact         qui      NaN         NaN     NaN
# 25  Mot exact         qui      NaN         NaN     NaN
# 26  Mot exact         qui      NaN         NaN     NaN
# 27  Mot exact         qui      NaN         NaN     NaN
# 28  Mot exact         qui      NaN         NaN     NaN
# 29  Mot exact         qui  ex situ  est-ce que  formed
# 30  Mot exact         qui  ex situ  est-ce que  formed
# 31  Mot exact         qui  ex situ  est-ce que  formed
# 32  Mot exact        quiS  ex situ  est-ce que  formed
# 33  Mot exact        quiS  ex situ  est-ce que  formed
# 34  Mot exact         qui      NaN         NaN     NaN
# 35  Mot exact         qui      NaN         NaN     NaN
# 36  Mot exact        quiS  ex situ  est-ce que  formed
# 37  Mot exact         qui  ex situ         NaN  formed
# 38  Mot exact         qui  ex situ  est-ce que  formed
# 39  Mot exact         qui  ex situ  est-ce que  formed
# 40  Mot exact         qui      NaN         NaN     NaN
# 41  Mot exact        quiS  ex situ  est-ce que  formed
# 42  Mot exact         qui      NaN         NaN     NaN
# 43  Mot exact         qui  ex situ  est-ce que  formed
# 44  Mot exact         qui  ex situ  est-ce que  formed
# 45  Mot exact         qui  ex situ         NaN  formed
# 46  Mot exact         qui      NaN         NaN     NaN
# 47  Mot exact         qui      NaN         NaN     NaN
# 48  Mot exact         qui  ex situ         NaN  formed
# 49  Mot exact         qui      NaN         NaN     NaN
# 50  Mot exact         qui  ex situ         NaN  formed
# 51  Mot exact         qui      NaN         NaN     NaN
# 52  Mot exact         qui      NaN         NaN     NaN
# 53  Mot exact        quiS  ex situ  est-ce que  formed
# 54  Mot exact         qui      NaN         NaN     NaN
# 55  Mot exact         qui  in situ          SV   final
# 56  Mot exact         qui      NaN         NaN     NaN
# 57  Mot exact         qui      NaN         NaN     NaN
# 58  Mot exact         qui  ex situ  est-ce que  formed
# 59  Mot exact         qui      NaN         NaN     NaN
#
#                                                    5               6   \
# 0                                             segment  enregistrement
# 1                trés bien qui habitent la rue hein ?   ESLO1_ENT_017
# 2                            qui habitent le ah bon ?   ESLO1_ENT_017
# 3   quelles sont les choses qui vous plaisent le p...   ESLO1_ENT_017
# 4   qu'est-ce que vous pensez des des femmes marié...   ESLO1_ENT_017
# 5   alors à Orléans qui est-ce qui va à la maison ...   ESLO1_ENT_017
# 6   quelles sont les p- les personnes qui comptent...   ESLO1_ENT_017
# 7   vous pouvez expliquer un peu ce qui s'est passé ?   ESLO1_ENT_017
# 8   parmi vos vos connaissances quelle serait la p...   ESLO1_ENT_017
# 9   est-ce qu'à votre avis en France y a un organi...   ESLO1_ENT_017
# 10  et vous personnellement qu'est-ce que vous pen...   ESLO1_ENT_018
# 11  est-ce qu'il y a des professions qui vous semb...   ESLO1_ENT_018
# 12  il y a encore des professions qui ne demandent...   ESLO1_ENT_018
# 13  en général c'est vous ou votre femme qui s'occ...   ESLO1_ENT_018
# 14  enfin c'est elle qui décide aussi par exemple ...   ESLO1_ENT_018
# 15  est-ce qu'il y a des matiéres qui vous paraiss...   ESLO1_ENT_018
# 16  et est-ce qu'il y a des matiéres qui vous semb...   ESLO1_ENT_018
# 17  et qu'est-ce que vous pensez des parents qui p...   ESLO1_ENT_018
# 18                       qui poussent leurs enfants ?   ESLO1_ENT_018
# 19  et comment vous expliquez qu'il y ait des enfa...   ESLO1_ENT_018
# 20  entre celui qui voit l'ensemble du probléme en...   ESLO1_ENT_018
# 21  vous en avez d'autres qui sont moins bien élev...   ESLO1_ENT_019
# 22  mais pour l'éléve moyen alors qui n'a pas beau...   ESLO1_ENT_019
# 23  j'allais vous demander est-ce que vous pourrie...   ESLO1_ENT_019
# 24  quelle est la personne qui parle le mieux le f...   ESLO1_ENT_019
# 25  y a-t-il en France euh un organisme officiel q...   ESLO1_ENT_019
# 26  et quelles sont les choses qui vous plaisent e...   ESLO1_ENT_020
# 27  je veux dire quelles sont les personnes à Orlé...   ESLO1_ENT_020
# 28  quel est le le la personne ou le type de profe...   ESLO1_ENT_020
# 29  est-ce que vous vous pensez qu'il y a en Franc...   ESLO1_ENT_020
# 30  et si vous deviez euh dire quelque chose à que...   ESLO1_ENT_020
# 31  est-ce que dans la façon de parler de de votre...   ESLO1_ENT_020
# 32  qui est-ce qui reprend l'autre le plus souvent...   ESLO1_ENT_020
# 33  qui est-ce qui reprenait votre pére ou votre m...   ESLO1_ENT_020
# 34           qu'est ce qui vous a amené à vivre ici ?   ESLO1_ENT_021
# 35  il n'y a pas de chose qui vous déplait alors d...   ESLO1_ENT_021
# 36  mais qui est-ce qui s'en sert le plus souvent ...   ESLO1_ENT_021
# 37  qui d'entre vous avait la meilleure orthograph...   ESLO1_ENT_021
# 38  dans le temps n'est-ce pas qui vous agaçaient ...   ESLO1_ENT_021
# 39  et ce match ce mois de juin qui vient qu'est-c...   ESLO1_ENT_022
# 40             il y a des gens qui parlent pas bien ?   ESLO1_ENT_022
# 41          qui est-ce qui s'en sert le plus souvent?   ESLO1_ENT_022
# 42                      c'est vous qui l'avez prise ?   ESLO1_ENT_023
# 43  qu'est-ce que vous pensez du travail des des f...   ESLO1_ENT_023
# 44  est-ce que parmi vos petits-enfants y en a qui...   ESLO1_ENT_023
# 45                                 qui sont arrivés ?   ESLO1_ENT_023
# 46  c'est un incendie qui était dû à quoi on sait ...   ESLO1_ENT_023
# 47  des gens qui se qui ont beaucoup d'influence à...   ESLO1_ENT_023
# 48                            qui comptent beaucoup ?   ESLO1_ENT_023
# 49  sur le plan social ou sur le plan politique ou...   ESLO1_ENT_023
# 50  qui avaient de l'influence jadis non ? ça ne ç...   ESLO1_ENT_023
# 51  et y a quelqu'un qui représente Jeanne d'Arc a...   ESLO1_ENT_023
# 52  baratineur celui qui cause facilement on celui...   ESLO1_ENT_023
# 53  autrement qui est-ce qui écrivait c'était vous...   ESLO1_ENT_023
# 54  euh y avait des choses qui vous agaçaient dans...   ESLO1_ENT_023
# 55                                         pour qui ?   ESLO1_ENT_024
# 56  à votre travail enfin avec qui parlez-vous au ...   ESLO1_ENT_024
# 57  et là je j'ai dit on mais on ça représente qui...   ESLO1_ENT_024
# 58  est-ce que vous pourriez m'expliquer un peu ce...   ESLO1_ENT_024
# 59  un étranger qui voudrait apprendre la langue f...   ESLO1_ENT_024
#
#                  7         8           9         10                11  \
# 0     transcription  locuteur  debut (ms)  fin (ms)  debut (hh:mm:ss)
# 1   ESLO1_ENT_017_C     QB100       97160     98641          0.001123
# 2   ESLO1_ENT_017_C        CS      370289    371481          0.004282
# 3   ESLO1_ENT_017_C        CS      734543    738206          0.008495
# 4   ESLO1_ENT_017_C        CS      768372    772569          0.008889
# 5   ESLO1_ENT_017_C        CS     1062853   1065278          0.012292
# 6   ESLO1_ENT_017_C        CS     1859247   1864205          0.021516
# 7   ESLO1_ENT_017_C        CS     2026649   2038217          0.023449
# 8   ESLO1_ENT_017_C        CS     3569081   3578155          0.041308
# 9   ESLO1_ENT_017_C        CS     3847779   3857143          0.044525
# 10  ESLO1_ENT_018_C        BV     1139919   1144385          0.013183
# 11  ESLO1_ENT_018_C        BV     1279241   1283616          0.014803
# 12  ESLO1_ENT_018_C        BV     1317345   1320876          0.015243
# 13  ESLO1_ENT_018_C        BV     1414283   1418346          0.016366
# 14  ESLO1_ENT_018_C        BV     1438347   1441988          0.016644
# 15  ESLO1_ENT_018_C        BV     1590539   1593008          0.018403
# 16  ESLO1_ENT_018_C        BV     1704331   1717361          0.019722
# 17  ESLO1_ENT_018_C        BV     1939500   1942375          0.022442
# 18  ESLO1_ENT_018_C     UF391     1946125   1947657          0.022523
# 19  ESLO1_ENT_018_C        BV     2249189   2252485           0.02603
# 20  ESLO1_ENT_018_C        BV     3437246   3442292           0.03978
# 21  ESLO1_ENT_019_C     UG393      480961    484282          0.005556
# 22  ESLO1_ENT_019_C        JK      676714    682012          0.007824
# 23  ESLO1_ENT_019_C        JK      841996    847457          0.009734
# 24  ESLO1_ENT_019_C        JK     2077143   2090469          0.024039
# 25  ESLO1_ENT_019_C        JK     2106289   2118170          0.024375
# 26  ESLO1_ENT_020_C        CS      108706    112775           0.00125
# 27  ESLO1_ENT_020_C        CS     1160931   1168571          0.013426
# 28  ESLO1_ENT_020_C        CS     2036641   2047510          0.023565
# 29  ESLO1_ENT_020_C        CS     2056097   2066903          0.023796
# 30  ESLO1_ENT_020_C        CS     2293642   2307156          0.026539
# 31  ESLO1_ENT_020_C        CS     2746674   2757501          0.031782
# 32  ESLO1_ENT_020_C        CS     2775747   2779064          0.032118
# 33  ESLO1_ENT_020_C        CS     2854673   2857436          0.033032
# 34  ESLO1_ENT_021_C        JK       23139     24858          0.000266
# 35  ESLO1_ENT_021_C        JK      217494    221815          0.002512
# 36  ESLO1_ENT_021_C        JK     4474041   4479016          0.051782
# 37  ESLO1_ENT_021_C        JK     5815527   5820988          0.067303
# 38  ESLO1_ENT_021_C        JK     6134363   6140209          0.070995
# 39  ESLO1_ENT_022_C        MD      406456    409300          0.004699
# 40  ESLO1_ENT_022_C        MD     1343540   1345187          0.015544
# 41  ESLO1_ENT_022_C        MD     1714702   1716319          0.019838
# 42  ESLO1_ENT_023_C        MB      503893    505780          0.005822
# 43  ESLO1_ENT_023_C        MB      529674    534165          0.006123
# 44  ESLO1_ENT_023_C        MB      867504    872834          0.010035
# 45  ESLO1_ENT_023_C        MB     1267255   1267938          0.014664
# 46  ESLO1_ENT_023_C        MB     1297353   1299772          0.015012
# 47  ESLO1_ENT_023_C        MB     1399133   1405266          0.016192
# 48  ESLO1_ENT_023_C        MB     1404457   1405266           0.01625
# 49  ESLO1_ENT_023_C        MB     1409901   1414356          0.016308
# 50  ESLO1_ENT_023_C        MB     1449024   1452947          0.016771
# 51  ESLO1_ENT_023_C        MB     1991136   1993891          0.023044
# 52  ESLO1_ENT_023_C     XZ501     2830017   2833141          0.032755
# 53  ESLO1_ENT_023_C        MB     3489741   3491601          0.040382
# 54  ESLO1_ENT_023_C        MB     3569290   3574212          0.041308
# 55  ESLO1_ENT_024_C      1134      363890    367167          0.004201
# 56  ESLO1_ENT_024_C        HM      915678    918835           0.01059
# 57  ESLO1_ENT_024_C        HM     2496151   2506892          0.028889
# 58  ESLO1_ENT_024_C        HM     2603908   2607705          0.030127
# 59  ESLO1_ENT_024_C      1134     2712914   2714846          0.031389
#
#                 12
# 0   fin (hh:mm:ss)
# 1         0.001134
# 2         0.004294
# 3         0.008542
# 4         0.008935
# 5         0.012326
# 6         0.021574
# 7         0.023588
# 8         0.041412
# 9         0.044641
# 10        0.013241
# 11         0.01485
# 12        0.015278
# 13        0.016412
# 14        0.016678
# 15        0.018437
# 16        0.019873
# 17        0.022477
# 18        0.022535
# 19        0.026065
# 20        0.039838
# 21        0.005602
# 22        0.007894
# 23        0.009803
# 24         0.02419
# 25        0.024514
# 26        0.001296
# 27        0.013519
# 28        0.023692
# 29        0.023912
# 30        0.026701
# 31         0.03191
# 32        0.032164
# 33        0.033067
# 34        0.000278
# 35        0.002558
# 36         0.05184
# 37        0.067361
# 38        0.071065
# 39        0.004734
# 40        0.015567
# 41        0.019861
# 42        0.005845
# 43        0.006181
# 44        0.010093
# 45        0.014664
# 46        0.015035
# 47        0.016262
# 48        0.016262
# 49        0.016366
# 50        0.016806
# 51        0.023067
# 52        0.032789
# 53        0.040405
# 54        0.041366
# 55        0.004248
# 56        0.010625
# 57        0.029005
# 58        0.030174
# 59        0.031412
