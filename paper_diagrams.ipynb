# %% [markdown]
# Visualisations for Baunaz & Bonan (2023)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick
from matplotlib.ticker import PercentFormatter
import matplotlib as mpl

# %% [markdown]
# Figure 1: Ex situ vs in situ over time: percentages

# %%
# color choice 1

plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [3.00, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['ESLO 1', 'ESLO 2']

# data
ex_situ = [81, 38]
in_situ = [19, 62]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, ex_situ, width, color='paleturquoise', label='ex situ')
rects2 = ax.bar(x + width/2, in_situ, width, color='mediumturquoise', label='in situ')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences')
ax.set_xlabel('Corpora')
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %%
# colour choice 2

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [3.00, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['ESLO 1', 'ESLO 2']

# data
ex_situ = [81, 38]
in_situ = [19, 62]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, ex_situ, width, color='cadetblue', label='ex situ')
rects2 = ax.bar(x + width/2, in_situ, width, color='darkturquoise', label='in situ')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Corpora', fontname="TimesNewRoman", fontsize=12)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %%
# colour choice 3

# colour choice 2

plt.style.use('bmh')
mpl.rcParams['figure.dpi'] = 300

plt.rcParams["figure.figsize"] = [4.00, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['ESLO 1', 'ESLO 2']

# data
ex_situ = [81, 38]
in_situ = [19, 62]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, ex_situ, width, color='lightskyblue', label='ex situ')
rects2 = ax.bar(x + width/2, in_situ, width, color='lightseagreen', label='in situ')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences')
ax.set_xlabel('Corpora')
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Figure 2: Proportion of ex situ vs in situ for each wh-word in ESLO 1.

# %%
# colour choise 2

plt.style.use('bmh')
mpl.rcParams['figure.dpi'] = 300

plt.rcParams["figure.figsize"] = [6.00, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['comment', 'où', 'quand', 'quiO', 'quoiO']

# data
ex_situ = [96, 74, 78, 88, 57]
in_situ = [4, 26, 22, 12, 43]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, ex_situ, width, color='cadetblue', label='ex situ')
rects2 = ax.bar(x + width/2, in_situ, width, color='darkturquoise', label='in situ')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Observed wh-words (ESLO 1)', fontname="TimesNewRoman", fontsize=12)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Figure 3: Proportion of ex situ vs in situ for each wh-word in ESLO 2.

# %%
# colour choice 2

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [6.00, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['comment', 'où', 'quand', 'quiO', 'quoiO']

# data
ex_situ = [71, 29, 52, 30, 6]
in_situ = [29, 71, 48, 70, 94]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, ex_situ, width, color='cadetblue', label='ex situ')
rects2 = ax.bar(x + width/2, in_situ, width, color='darkturquoise', label='in situ')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Observed wh-words (ESLO 2)', fontname="TimesNewRoman", fontsize=12)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Figure 4: Proportion of in situ occurrences for each wh-word in micro-diachrony (1970s-2010s).

# %%
# colour code 3

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [6.00, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['quoiO', 'où', 'comment', 'quand', 'quiO']

# data
eslo_1 = [57, 24, 11, 7, 1]
eslo_2 = [49, 27, 18, 4, 2]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, eslo_1, width, color='slateblue', label='ESLO 1')
rects2 = ax.bar(x + width/2, eslo_2, width, color='darkorchid', label='ESLO 2')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of in-situ occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Observed wh-words (ESLO 1 vs ESLO 2)', fontname="TimesNewRoman", fontsize=12)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Figure 5: Proportions of wh in-situ according to their level of activation (EACT, N-ACT and INF) in micro-diachrony.

# %%
# colour code 3

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [4.50, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['EACT', 'N-ACT', 'INF']

# data
eslo_1 = [19, 8, 73]
eslo_2 = [16, 34, 50]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, eslo_1, width, color='slateblue', label='ESLO 1')
rects2 = ax.bar(x + width/2, eslo_2, width, color='darkorchid', label='ESLO 2')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Activation levels (ESLO 1 vs ESLO 2)', fontname="TimesNewRoman", fontsize=12)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Figure 6: Activation levels in ESLO 1

# %%
# colour code 4

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [5.50, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['quoiO', 'où', 'comment']

# data
eact = [17, 21, 22]
nact = [3, 20, 9]
inf = [80, 59, 69]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width, eact, width, color='peachpuff', label='EACT')
rects2 = ax.bar(x, nact, width, color='darksalmon', label='N-ACT')
rects3 = ax.bar(x + width, inf, width, color='lightcoral', label='INF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Activation levels for the selected wh-words (ESLO 1)', fontname="TimesNewRoman", fontsize=11)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects3:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Figure 7: Activation levels in ESLO 2

# %%
# colour code 4

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [5.50, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['quoiO', 'où', 'comment']

# data
eact = [17, 14, 14]
nact = [30, 40, 40]
inf = [53, 46, 46]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width, eact, width, color='peachpuff', label='EACT')
rects2 = ax.bar(x, nact, width, color='darksalmon', label='N-ACT')
rects3 = ax.bar(x + width, inf, width, color='lightcoral', label='INF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Activation levels for the selected wh-words (ESLO 2)', fontname="TimesNewRoman", fontsize=11)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects3:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Quoi in situ: activation evolution

# %%
# colour code 2

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [4.50, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['EACT', 'N-ACT', 'INF']

# data
eslo_1 = [17, 3, 80]
eslo_2 = [17, 30, 53]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, eslo_1, width, color='cadetblue', label='ESLO 1')
rects2 = ax.bar(x + width/2, eslo_2, width, color='darkturquoise', label='ESLO 2')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('QuoiO: activation status (ESLO 1 vs ESLO 2)', fontname="TimesNewRoman", fontsize=11)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Où in situ: activation evolution

# %%
# colour code 2

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [4.50, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['EACT', 'N-ACT', 'INF']

# data
eslo_1 = [21, 20, 59]
eslo_2 = [14, 40, 46]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, eslo_1, width, color='cadetblue', label='ESLO 1')
rects2 = ax.bar(x + width/2, eslo_2, width, color='darkturquoise', label='ESLO 2')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Où: activation status (ESLO 1 vs ESLO 2)', fontname="TimesNewRoman", fontsize=11)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()

# %% [markdown]
# Comment in situ: activation evolution

# %%
# colour code 2

mpl.rcParams['figure.dpi'] = 300
plt.style.use('bmh')

plt.rcParams["figure.figsize"] = [4.50, 4.00]
plt.rcParams["figure.autolayout"] = True

labels = ['EACT', 'N-ACT', 'INF']

# data
eslo_1 = [22, 9, 69]
eslo_2 = [14, 40, 46]

x = np.arange(len(labels))  # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots()
# ax.yaxis.set_major_formatter(mtick.PercentFormatter(5.0))
rects1 = ax.bar(x - width/2, eslo_1, width, color='cadetblue', label='ESLO 1')
rects2 = ax.bar(x + width/2, eslo_2, width, color='darkturquoise', label='ESLO 2')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences', fontname="TimesNewRoman", fontsize=12)
ax.set_xlabel('Comment: activation status (ESLO 1 vs ESLO 2)', fontname="TimesNewRoman", fontsize=12)
ax.set_xticks(x, labels)
ax.legend()

for p in rects1:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

for p in rects2:
   height = p.get_height()
   ax.text(x=p.get_x() + p.get_width() / 2, y=height+.10,
      s="{}%".format(height),
      ha='center')

plt.show()
